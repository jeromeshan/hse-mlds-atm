# %%
import osmium 
import pandas as pd
import geopandas as gpd
import glob
import os

# %% [markdown]
# [GeoFabric Russian Federal Districts](https://download.geofabrik.de/russia.html)

# %%
df = pd.read_csv('found_cut.csv')

groups = [
    'amenity',
    'place',
    'building',
    'craft',
    'healthcare',
    'historic',
    'leisure',
    'office',
    'shop',
    'tourism',    
]

df2 = df[df['key'].isin(groups)].drop_duplicates()

def full_tag_name(row):
    key, value = row['key'], row['value']
    return f'{key}::{value}'

tag_names = df2.apply(full_tag_name, axis=1).tolist()
tag_list = [{i:[j]} for i, j in list(zip(df2['key'].tolist(), df2['value'].tolist()))]
tags = dict(zip(tag_names, tag_list))

sorted([(i,j) for i,j in zip(df2['key'].tolist(), df2['value'].tolist())], key=lambda x:x[0])
# Out:
# [('amenity', 'bar'),
#  ('amenity', 'pub'),
#  ('amenity', 'restaurant'),
#  ('amenity', 'biergarten'),
#  ('amenity', 'cafe'),
#  ('amenity', 'fast_food'),
#  ('amenity', 'food_court'),
#  ('amenity', 'ice_cream'),
#  ('amenity', 'college'),
#  ('amenity', 'driving_school'),
#  ('amenity', 'kindergarten'),
#  ('amenity', 'language_school'),
#  ('amenity', 'library'),
#  ('amenity', 'toy_library'),
#  ('amenity', 'training'),
#  ('amenity', 'music_school'),
#  ('amenity', 'school'),
#  ('amenity', 'university'),
#  ('amenity', 'bicycle_parking'),
#  ('amenity', 'bicycle_repair_station'),
#  ('amenity', 'bicycle_rental'),
#  ('amenity', 'boat_rental'),
#  ('amenity', 'boat_sharing'),
#  ('amenity', 'bus_station'),
#  ('amenity', 'car_rental'),
#  ('amenity', 'car_sharing'),
#  ('amenity', 'car_wash'),
#  ('amenity', 'compressed_air'),
#  ('amenity', 'vehicle_inspection'),
#  ('amenity', 'charging_station'),
#  ('amenity', 'ferry_terminal'),
#  ('amenity', 'fuel'),
#  ('amenity', 'grit_bin'),
#  ('amenity', 'motorcycle_parking'),
#  ('amenity', 'parking'),
#  ('amenity', 'parking_entrance'),
#  ('amenity', 'parking_space'),
#  ('amenity', 'taxi'),
#  ('amenity', 'atm'),
#  ('amenity', 'bank'),
#  ('amenity', 'bureau_de_change'),
#  ('amenity', 'baby_hatch'),
#  ('amenity', 'clinic'),
#  ('amenity', 'dentist'),
#  ('amenity', 'doctors'),
#  ('amenity', 'hospital'),
#  ('amenity', 'nursing_home'),
#  ('amenity', 'social_facility'),
#  ('amenity', 'pharmacy'),
#  ('amenity', 'veterinary'),
#  ('amenity', 'arts_centre'),
#  ('amenity', 'brothel'),
#  ('amenity', 'casino'),
#  ('amenity', 'cinema'),
#  ('amenity', 'community_centre'),
#  ('amenity', 'conference_centre'),
#  ('amenity', 'events_venue'),
#  ('amenity', 'fountain'),
#  ('amenity', 'gambling'),
#  ('amenity', 'love_hotel'),
#  ('amenity', 'nightclub'),
#  ('amenity', 'stripclub'),
#  ('amenity', 'planetarium'),
#  ('amenity', 'public_bookcase'),
#  ('amenity', 'social_centre'),
#  ('amenity', 'studio'),
#  ('amenity', 'swingerclub'),
#  ('amenity', 'theatre'),
#  ('amenity', 'courthouse'),
#  ('amenity', 'fire_station'),
#  ('amenity', 'police'),
#  ('amenity', 'post_box'),
#  ('amenity', 'post_depot'),
#  ('amenity', 'post_office'),
#  ('amenity', 'prison'),
#  ('amenity', 'ranger_station'),
#  ('amenity', 'townhall'),
#  ('amenity', 'bbq'),
#  ('amenity', 'bench'),
#  ('amenity', 'dog_toilet'),
#  ('amenity', 'dressing_room'),
#  ('amenity', 'drinking_water'),
#  ('amenity', 'give_box'),
#  ('amenity', 'mailroom'),
#  ('amenity', 'parcel_locker'),
#  ('amenity', 'shelter'),
#  ('amenity', 'shower'),
#  ('amenity', 'telephone'),
#  ('amenity', 'toilets'),
#  ('amenity', 'water_point'),
#  ('amenity', 'watering_place'),
#  ('amenity', 'sanitary_dump_station'),
#  ('amenity', 'recycling'),
#  ('amenity', 'waste_basket'),
#  ('amenity', 'waste_disposal'),
#  ('amenity', 'waste_transfer_station'),
#  ('amenity', 'animal_boarding'),
#  ('amenity', 'animal_breeding'),
#  ('amenity', 'animal_shelter'),
#  ('amenity', 'baking_oven'),
#  ('amenity', 'childcare'),
#  ('amenity', 'clock'),
#  ('amenity', 'crematorium'),
#  ('amenity', 'dive_centre'),
#  ('amenity', 'funeral_hall'),
#  ('amenity', 'grave_yard'),
#  ('amenity', 'hunting_stand'),
#  ('amenity', 'internet_cafe'),
#  ('amenity', 'kitchen'),
#  ('amenity', 'kneipp_water_cure'),
#  ('amenity', 'lounger'),
#  ('amenity', 'marketplace'),
#  ('amenity', 'monastery'),
#  ('amenity', 'photo_booth'),
#  ('amenity', 'place_of_mourning'),
#  ('amenity', 'place_of_worship'),
#  ('amenity', 'public_bath'),
#  ('amenity', 'public_building'),
#  ('amenity', 'refugee_site'),
#  ('amenity', 'vending_machine'),
#  ('building', 'bakehouse'),
#  ('building', 'supermarket'),
#  ('building', 'apartments'),
#  ('building', 'barracks'),
#  ('building', 'bungalow'),
#  ('building', 'cabin'),
#  ('building', 'detached'),
#  ('building', 'dormitory'),
#  ('building', 'farm'),
#  ('building', 'farm_auxiliary'),
#  ('building', 'barn'),
#  ('building', 'house'),
#  ('building', 'ger'),
#  ('building', 'hotel'),
#  ('building', 'houseboat'),
#  ('building', 'residential'),
#  ('building', 'semidetached_house'),
#  ('building', 'static_caravan'),
#  ('building', 'stilt_house'),
#  ('building', 'terrace'),
#  ('building', 'tree_house'),
#  ('building', 'commercial'),
#  ('building', 'industrial'),
#  ('building', 'kiosk'),
#  ('building', 'office'),
#  ('building', 'retail'),
#  ('building', 'warehouse'),
#  ('building', 'cathedral'),
#  ('building', 'chapel'),
#  ('building', 'church'),
#  ('building', 'kingdom_hall'),
#  ('building', 'monastery'),
#  ('building', 'mosque'),
#  ('building', 'presbytery'),
#  ('building', 'religious'),
#  ('building', 'shrine'),
#  ('building', 'synagogue'),
#  ('building', 'temple'),
#  ('building', 'bridge'),
#  ('building', 'gatehouse'),
#  ('building', 'civic'),
#  ('building', 'public'),
#  ('building', 'college'),
#  ('building', 'fire_station'),
#  ('building', 'government'),
#  ('building', 'hospital'),
#  ('building', 'kindergarten'),
#  ('building', 'school'),
#  ('building', 'toilets'),
#  ('building', 'train_station'),
#  ('building', 'transportation'),
#  ('building', 'university'),
#  ('building', 'conservatory'),
#  ('building', 'cowshed'),
#  ('building', 'greenhouse'),
#  ('building', 'slurry_tank'),
#  ('building', 'stable'),
#  ('building', 'sty'),
#  ('building', 'grandstand'),
#  ('building', 'pavilion'),
#  ('building', 'riding_hall'),
#  ('building', 'sports_hall'),
#  ('building', 'stadium'),
#  ('building', 'hangar'),
#  ('building', 'hut'),
#  ('building', 'shed'),
#  ('building', 'carport'),
#  ('building', 'garage'),
#  ('building', 'garages'),
#  ('building', 'parking'),
#  ('building', 'digester'),
#  ('building', 'service'),
#  ('building', 'transformer_tower'),
#  ('building', 'water_tower'),
#  ('building', 'storage_tank'),
#  ('building', 'silo'),
#  ('building', 'beach_hut'),
#  ('building', 'bunker'),
#  ('building', 'castle'),
#  ('building', 'construction'),
#  ('building', 'container'),
#  ('building', 'military'),
#  ('building', 'roof'),
#  ('building', 'ruins'),
#  ('building', 'tent'),
#  ('building', 'yes'),
#  ('building', 'entrance'),
#  ('craft', 'agricultural_engines'),
#  ('craft', 'atelier'),
#  ('craft', 'bakery'),
#  ('craft', 'basket_maker'),
#  ('craft', 'beekeeper'),
#  ('craft', 'blacksmith'),
#  ('craft', 'boatbuilder'),
#  ('craft', 'bookbinder'),
#  ('craft', 'brewery'),
#  ('craft', 'builder'),
#  ('craft', 'cabinet_maker'),
#  ('craft', 'candlemaker'),
#  ('craft', 'car_painter'),
#  ('craft', 'carpenter'),
#  ('craft', 'carpet_layer'),
#  ('craft', 'caterer'),
#  ('craft', 'chimney_sweeper'),
#  ('craft', 'cleaning'),
#  ('craft', 'clockmaker'),
#  ('craft', 'confectionery'),
#  ('craft', 'cooper'),
#  ('craft', 'dental_technician'),
#  ('craft', 'distillery'),
#  ('craft', 'door_construction'),
#  ('craft', 'dressmaker'),
#  ('craft', 'electronics_repair'),
#  ('craft', 'embroiderer'),
#  ('craft', 'electrician'),
#  ('craft', 'engraver'),
#  ('craft', 'fence_maker'),
#  ('craft', 'floorer'),
#  ('craft', 'fruit_press'),
#  ('craft', 'gardener'),
#  ('craft', 'glaziery'),
#  ('craft', 'goldsmith'),
#  ('craft', 'grinding_mill'),
#  ('craft', 'handicraft'),
#  ('craft', 'hvac'),
#  ('craft', 'insulation'),
#  ('craft', 'interior_decorator'),
#  ('craft', 'interior_work'),
#  ('craft', 'jeweller'),
#  ('craft', 'joiner'),
#  ('craft', 'key_cutter'),
#  ('craft', 'locksmith'),
#  ('craft', 'metal_construction'),
#  ('craft', 'mint'),
#  ('craft', 'musical_instrument'),
#  ('craft', 'oil_mill'),
#  ('craft', 'optician'),
#  ('craft', 'organ_builder'),
#  ('craft', 'painter'),
#  ('craft', 'parquet_layer'),
#  ('craft', 'paver'),
#  ('craft', 'photographer'),
#  ('craft', 'photographic_laboratory'),
#  ('craft', 'piano_tuner'),
#  ('craft', 'plasterer'),
#  ('craft', 'plumber'),
#  ('craft', 'pottery'),
#  ('craft', 'printer'),
#  ('craft', 'printmaker'),
#  ('craft', 'rigger'),
#  ('craft', 'roofer'),
#  ('craft', 'saddler'),
#  ('craft', 'sailmaker'),
#  ('craft', 'sawmill'),
#  ('craft', 'scaffolder'),
#  ('craft', 'sculptor'),
#  ('craft', 'shoemaker'),
#  ('craft', 'signmaker'),
#  ('craft', 'stand_builder'),
#  ('craft', 'stonemason'),
#  ('craft', 'stove_fitter'),
#  ('craft', 'sun_protection'),
#  ('craft', 'tailor'),
#  ('craft', 'tiler'),
#  ('craft', 'tinsmith'),
#  ('craft', 'toolmaker'),
#  ('craft', 'turner'),
#  ('craft', 'upholsterer'),
#  ('craft', 'watchmaker'),
#  ('craft', 'water_well_drilling'),
#  ('craft', 'window_construction'),
#  ('craft', 'winery'),
#  ('healthcare', 'alternative'),
#  ('healthcare', 'yes'),
#  ('healthcare', 'audiologist'),
#  ('healthcare', 'birthing_centre'),
#  ('healthcare', 'blood_bank'),
#  ('healthcare', 'blood_donation'),
#  ('healthcare', 'counselling'),
#  ('healthcare', 'nutrition_counselling'),
#  ('healthcare', 'dialysis'),
#  ('healthcare', 'hospice'),
#  ('healthcare', 'laboratory'),
#  ('healthcare', 'midwife'),
#  ('healthcare', 'nurse'),
#  ('healthcare', 'occupational_therapist'),
#  ('healthcare', 'optometrist'),
#  ('healthcare', 'physiotherapist'),
#  ('healthcare', 'podiatrist'),
#  ('healthcare', 'psychotherapist'),
#  ('healthcare', 'rehabilitation'),
#  ('healthcare', 'sample_collection'),
#  ('healthcare', 'speech_therapist'),
#  ('healthcare', 'vaccination_centre'),
#  ('historic', 'boundary_stone'),
#  ('historic', 'monastery'),
#  ('historic', 'wayside_shrine'),
#  ('historic', 'castle'),
#  ('historic', 'aircraft'),
#  ('historic', 'anchor'),
#  ('historic', 'aqueduct'),
#  ('historic', 'archaeological_site'),
#  ('historic', 'battlefield'),
#  ('historic', 'bomb_crater'),
#  ('historic', 'building'),
#  ('historic', 'cannon'),
#  ('historic', 'castle_wall'),
#  ('historic', 'cattle_crush'),
#  ('historic', 'charcoal_pile'),
#  ('historic', 'church'),
#  ('historic', 'city_gate'),
#  ('historic', 'citywalls'),
#  ('historic', 'creamery'),
#  ('historic', 'district'),
#  ('historic', 'farm'),
#  ('historic', 'fort'),
#  ('historic', 'gallows'),
#  ('historic', 'highwater_mark'),
#  ('historic', 'locomotive'),
#  ('historic', 'manor'),
#  ('historic', 'memorial'),
#  ('historic', 'milestone'),
#  ('historic', 'monument'),
#  ('historic', 'ogham_stone'),
#  ('historic', 'optical_telegraph'),
#  ('historic', 'pa'),
#  ('historic', 'pillory'),
#  ('historic', 'railway_car'),
#  ('historic', 'road'),
#  ('historic', 'ruins'),
#  ('historic', 'rune_stone'),
#  ('historic', 'shieling'),
#  ('historic', 'ship'),
#  ('historic', 'stone'),
#  ('historic', 'tank'),
#  ('historic', 'tomb'),
#  ('historic', 'tower'),
#  ('historic', 'vehicle'),
#  ('historic', 'wayside_cross'),
#  ('historic', 'wreck'),
#  ('historic', 'yes'),
#  ('leisure', 'adult_gaming_centre'),
#  ('leisure', 'firepit'),
#  ('leisure', 'sports_centre'),
#  ('leisure', 'swimming_pool'),
#  ('leisure', 'amusement_arcade'),
#  ('leisure', 'beach_resort'),
#  ('leisure', 'bandstand'),
#  ('leisure', 'bird_hide'),
#  ('leisure', 'common'),
#  ('leisure', 'dance'),
#  ('leisure', 'disc_golf_course'),
#  ('leisure', 'dog_park'),
#  ('leisure', 'escape_game'),
#  ('leisure', 'fishing'),
#  ('leisure', 'fitness_centre'),
#  ('leisure', 'fitness_station'),
#  ('leisure', 'garden'),
#  ('leisure', 'hackerspace'),
#  ('leisure', 'horse_riding'),
#  ('leisure', 'ice_rink'),
#  ('leisure', 'marina'),
#  ('leisure', 'miniature_golf'),
#  ('leisure', 'nature_reserve'),
#  ('leisure', 'park'),
#  ('leisure', 'picnic_table'),
#  ('leisure', 'pitch'),
#  ('leisure', 'playground'),
#  ('leisure', 'slipway'),
#  ('leisure', 'stadium'),
#  ('leisure', 'summer_camp'),
#  ('leisure', 'swimming_area'),
#  ('leisure', 'track'),
#  ('leisure', 'water_park'),
#  ('office', 'government'),
#  ('office', 'ngo'),
#  ('office', 'association'),
#  ('office', 'accountant'),
#  ('office', 'administrative'),
#  ('office', 'advertising_agency'),
#  ('office', 'architect'),
#  ('office', 'chamber'),
#  ('office', 'charity'),
#  ('office', 'company'),
#  ('office', 'construction_company'),
#  ('office', 'consulting'),
#  ('office', 'courier'),
#  ('office', 'coworking'),
#  ('office', 'diplomatic'),
#  ('office', 'educational_institution'),
#  ('office', 'employment_agency'),
#  ('office', 'energy_supplier'),
#  ('office', 'engineer'),
#  ('office', 'estate_agent'),
#  ('office', 'financial'),
#  ('office', 'financial_advisor'),
#  ('office', 'forestry'),
#  ('office', 'foundation'),
#  ('office', 'geodesist'),
#  ('office', 'graphic_design'),
#  ('office', 'guide'),
#  ('office', 'harbour_master'),
#  ('office', 'insurance'),
#  ('office', 'it'),
#  ('office', 'lawyer'),
#  ('office', 'logistics'),
#  ('office', 'moving_company'),
#  ('office', 'newspaper'),
#  ('office', 'notary'),
#  ('office', 'politician'),
#  ('office', 'political_party'),
#  ('office', 'property_management'),
#  ('office', 'quango'),
#  ('office', 'religion'),
#  ('office', 'research'),
#  ('office', 'security'),
#  ('office', 'surveyor'),
#  ('office', 'tax_advisor'),
#  ('office', 'telecommunication'),
#  ('office', 'therapist'),
#  ('office', 'travel_agent'),
#  ('office', 'tutoring'),
#  ('office', 'union'),
#  ('office', 'visa'),
#  ('office', 'water_utility'),
#  ('office', 'yes'),
#  ('place', 'country'),
#  ('place', 'state'),
#  ('place', 'region'),
#  ('place', 'province'),
#  ('place', 'district'),
#  ('place', 'county'),
#  ('place', 'municipality'),
#  ('place', 'city'),
#  ('place', 'borough'),
#  ('place', 'suburb'),
#  ('place', 'quarter'),
#  ('place', 'neighbourhood'),
#  ('place', 'city_block'),
#  ('place', 'plot'),
#  ('place', 'town'),
#  ('place', 'village'),
#  ('place', 'hamlet'),
#  ('place', 'isolated_dwelling'),
#  ('place', 'farm'),
#  ('place', 'allotments'),
#  ('place', 'continent'),
#  ('place', 'archipelago'),
#  ('place', 'island'),
#  ('place', 'islet'),
#  ('place', 'square'),
#  ('place', 'locality'),
#  ('place', 'sea'),
#  ('place', 'ocean'),
#  ('shop', 'bookmaker'),
#  ('shop', 'lottery'),
#  ('shop', 'supermarket'),
#  ('shop', 'hearing_aids'),
#  ('shop', 'optician'),
#  ('shop', 'alcohol'),
#  ('shop', 'bakery'),
#  ('shop', 'beverages'),
#  ('shop', 'brewing_supplies'),
#  ('shop', 'butcher'),
#  ('shop', 'cheese'),
#  ('shop', 'chocolate'),
#  ('shop', 'coffee'),
#  ('shop', 'confectionery'),
#  ('shop', 'convenience'),
#  ('shop', 'deli'),
#  ('shop', 'dairy'),
#  ('shop', 'farm'),
#  ('shop', 'frozen_food'),
#  ('shop', 'greengrocer'),
#  ('shop', 'health_food'),
#  ('shop', 'ice_cream'),
#  ('shop', 'organic'),
#  ('shop', 'pasta'),
#  ('shop', 'pastry'),
#  ('shop', 'seafood'),
#  ('shop', 'spices'),
#  ('shop', 'tea'),
#  ('shop', 'wine'),
#  ('shop', 'water'),
#  ('shop', 'department_store'),
#  ('shop', 'mall'),
#  ('shop', 'general'),
#  ('shop', 'kiosk'),
#  ('shop', 'wholesale'),
#  ('shop', 'baby_goods'),
#  ('shop', 'bag'),
#  ('shop', 'boutique'),
#  ('shop', 'clothes'),
#  ('shop', 'fabric'),
#  ('shop', 'fashion'),
#  ('shop', 'jewelry'),
#  ('shop', 'leather'),
#  ('shop', 'sewing'),
#  ('shop', 'shoes'),
#  ('shop', 'tailor'),
#  ('shop', 'watches'),
#  ('shop', 'wool'),
#  ('shop', 'charity'),
#  ('shop', 'second_hand'),
#  ('shop', 'pawnbroker'),
#  ('shop', 'variety_store'),
#  ('shop', 'beauty'),
#  ('shop', 'hairdresser'),
#  ('shop', 'chemist'),
#  ('shop', 'cosmetics'),
#  ('shop', 'erotic'),
#  ('shop', 'hairdresser_supply'),
#  ('shop', 'herbalist'),
#  ('shop', 'massage'),
#  ('shop', 'medical_supply'),
#  ('shop', 'nutrition_supplements'),
#  ('shop', 'perfumery'),
#  ('shop', 'tattoo'),
#  ('shop', 'agrarian'),
#  ('shop', 'appliance'),
#  ('shop', 'bathroom_furnishing'),
#  ('shop', 'doityourself'),
#  ('shop', 'electrical'),
#  ('shop', 'energy'),
#  ('shop', 'fireplace'),
#  ('shop', 'florist'),
#  ('shop', 'garden_centre'),
#  ('shop', 'garden_furniture'),
#  ('shop', 'gas'),
#  ('shop', 'glaziery'),
#  ('shop', 'groundskeeping'),
#  ('shop', 'hardware'),
#  ('shop', 'houseware'),
#  ('shop', 'locksmith'),
#  ('shop', 'paint'),
#  ('shop', 'security'),
#  ('shop', 'trade'),
#  ('shop', 'windows'),
#  ('shop', 'antiques'),
#  ('shop', 'bed'),
#  ('shop', 'candles'),
#  ('shop', 'carpet'),
#  ('shop', 'curtain'),
#  ('shop', 'doors'),
#  ('shop', 'flooring'),
#  ('shop', 'furniture'),
#  ('shop', 'household_linen'),
#  ('shop', 'interior_decoration'),
#  ('shop', 'kitchen'),
#  ('shop', 'lamps'),
#  ('shop', 'lighting'),
#  ('shop', 'tiles'),
#  ('shop', 'window_blind'),
#  ('shop', 'computer'),
#  ('shop', 'electronics'),
#  ('shop', 'hifi'),
#  ('shop', 'mobile_phone'),
#  ('shop', 'radiotechnics'),
#  ('shop', 'vacuum_cleaner'),
#  ('shop', 'atv'),
#  ('shop', 'bicycle'),
#  ('shop', 'boat'),
#  ('shop', 'car'),
#  ('shop', 'car_repair'),
#  ('shop', 'car_parts'),
#  ('shop', 'caravan'),
#  ('shop', 'fuel'),
#  ('shop', 'fishing'),
#  ('shop', 'golf'),
#  ('shop', 'hunting'),
#  ('shop', 'jetski'),
#  ('shop', 'military_surplus'),
#  ('shop', 'motorcycle'),
#  ('shop', 'outdoor'),
#  ('shop', 'scuba_diving'),
#  ('shop', 'ski'),
#  ('shop', 'snowmobile'),
#  ('shop', 'sports'),
#  ('shop', 'swimming_pool'),
#  ('shop', 'trailer'),
#  ('shop', 'tyres'),
#  ('shop', 'art'),
#  ('shop', 'camera'),
#  ('shop', 'collector'),
#  ('shop', 'craft'),
#  ('shop', 'frame'),
#  ('shop', 'games'),
#  ('shop', 'model'),
#  ('shop', 'music'),
#  ('shop', 'musical_instrument'),
#  ('shop', 'photo'),
#  ('shop', 'trophy'),
#  ('shop', 'video'),
#  ('shop', 'video_games'),
#  ('shop', 'anime'),
#  ('shop', 'books'),
#  ('shop', 'gift'),
#  ('shop', 'newsagent'),
#  ('shop', 'stationery'),
#  ('shop', 'ticket'),
#  ('shop', 'cannabis'),
#  ('shop', 'copyshop'),
#  ('shop', 'dry_cleaning'),
#  ('shop', 'e-cigarette'),
#  ('shop', 'funeral_directors'),
#  ('shop', 'insurance'),
#  ('shop', 'laundry'),
#  ('shop', 'money_lender'),
#  ('shop', 'outpost'),
#  ('shop', 'party'),
#  ('shop', 'pest_control'),
#  ('shop', 'pet'),
#  ('shop', 'pet_grooming'),
#  ('shop', 'pyrotechnics'),
#  ('shop', 'religion'),
#  ('shop', 'storage_rental'),
#  ('shop', 'tobacco'),
#  ('shop', 'toys'),
#  ('shop', 'travel_agency'),
#  ('shop', 'weapons'),
#  ('shop', 'vacant'),
#  ('shop', 'yes'),
#  ('tourism', 'picnic_site'),
#  ('tourism', 'hotel'),
#  ('tourism', 'alpine_hut'),
#  ('tourism', 'apartment'),
#  ('tourism', 'aquarium'),
#  ('tourism', 'artwork'),
#  ('tourism', 'attraction'),
#  ('tourism', 'camp_pitch'),
#  ('tourism', 'camp_site'),
#  ('tourism', 'caravan_site'),
#  ('tourism', 'chalet'),
#  ('tourism', 'gallery'),
#  ('tourism', 'guest_house'),
#  ('tourism', 'hostel'),
#  ('tourism', 'information'),
#  ('tourism', 'motel'),
#  ('tourism', 'museum'),
#  ('tourism', 'theme_park'),
#  ('tourism', 'viewpoint'),
#  ('tourism', 'wilderness_hut'),
#  ('tourism', 'zoo'),
#  ('tourism', 'yes')]

# %%
def get_osmium_script(initial_file, output_file, tags):
    
    '''Функция возвращает скрипт osmium-tool обрезающую pbf по листу тегов
    
    initial_file -- путь к целому pbf файлу
    output_file --  название/путь файла обрезанного pbf файла 
    tags -- словарь с osm тегами
    '''
    
    osmium_string = f'osmium tags-filter {initial_file} '
    for name, tag in tags.items():
        for key, value_list in tag.items():
            if len(value_list) == 1:
                osmium_string += r'n/{}={} '.format(key, value_list[0])
            else:
                for value in value_list:
                    osmium_string += r'n/{}={} '.format(key, value)
    osmium_string += f'-o {output_file}'
    
    return osmium_string

# %% [markdown]
# [GeoFabric Russian Federal Districts](https://download.geofabrik.de/russia.html)

# %%
# Собираем лист с путями к цельным pbf файлам (скачаны с GeoFabric по ссылке выше)
input_files = glob.glob('/home/Irina/osm/*.osm.pbf')
# Собираем скрипт для каждого файла из списка
# Исполняем их и сохраняем обрезанные файлы в отдельную дерикторию fed_districts
for file in input_files:
    file_name = file[file.rfind('/') + 1:]
    os.system(get_osmium_script(file, 'fed_districts/cutted-{}'.format(file_name), tags))

# %%
# Создаем SimpleHandler для парсинга нужной информации из обрезанных pbf
class OSMHandler(osmium.SimpleHandler):
    def __init__(self):
        super(OSMHandler, self).__init__()
        self.infrastructure = []

    def node(self, o):
        for name, tag in tags.items():
            for key, value_list in tag.items():
                if len(value_list) == 1:
                    if o.tags.get(key) == value_list[0]:
                        self.infrastructure.append(
                            [name, o.location.lon, o.location.lat]
                        )
                else:
                    for value in value_list:
                        if o.tags.get(key) == value:
                            self.infrastructure.append(
                                [name, o.location.lon, o.location.lat]
                            )

# %%
# Названия обрезанных pbf файлов
osm_files = glob.glob('fed_districts/*.osm.pbf')

# Инициализируем словарик геофреймов
districts_gdfs = {}

# Итерируем над обрезанными pbf файлами
# Парсим из них инфо по тегам
# Записываем в геофрейм и крепим к словарю
for district in osm_files:
    handler = OSMHandler()
    handler.apply_file(district, locations=True)
    df = pd.DataFrame(handler.infrastructure, columns=['type', 'lon', 'lat'])
    gdf = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df['lon'], df['lat']))
    gdf.crs = 'EPSG:4326'
    districts_gdfs[district.replace('fed_districts/', '').replace('-latest.osm.pbf', '')] = gdf

# %%
# Сохраняем все в csv
for name, gdf in districts_gdfs.items():
    gdf.to_csv('fed_districts/' + name + '.csv')

# %%
objs = gpd.read_file('fed_districts/cutted-central-fed-district.csv')

# %%
objs['type'].drop_duplicates().tolist()
# Out:
# ['shop::supermarket',
#  'place::city',
#  'place::town',
#  'place::village',
#  'place::hamlet',
#  'amenity::cinema',
#  'place::suburb',
#  'tourism::attraction',
#  'amenity::place_of_worship',
#  'building::church',
#  'tourism::museum',
#  'tourism::hotel',
#  'amenity::pharmacy',
#  'amenity::theatre',
#  'amenity::cafe',
#  'amenity::clock',
#  'historic::memorial',
#  'amenity::bank',
#  'historic::monument',
#  'amenity::restaurant',
#  'shop::car_repair',
#  'shop::car_parts',
#  'amenity::post_office',
#  'amenity::police',
#  'amenity::telephone',
#  'historic::city_gate',
#  'place::locality',
#  'place::neighbourhood',
#  'historic::boundary_stone',
#  'amenity::atm',
#  'amenity::ferry_terminal',
#  'amenity::fast_food',
#  'amenity::bar',
#  'amenity::post_box',
#  'shop::convenience',
#  'historic::locomotive',
#  'shop::beauty',
#  'shop::clothes',
#  'shop::books',
#  'amenity::doctors',
#  'office::telecommunication',
#  'shop::mobile_phone',
#  'shop::kiosk',
#  'amenity::clinic',
#  'shop::electronics',
#  'shop::doityourself',
#  'shop::cosmetics',
#  'leisure::bandstand',
#  'amenity::pub',
#  'place::allotments',
#  'amenity::language_school',
#  'tourism::viewpoint',
#  'place::isolated_dwelling',
#  'amenity::library',
#  'amenity::marketplace',
#  'shop::bicycle',
#  'tourism::motel',
#  'historic::manor',
#  'amenity::bus_station',
#  'tourism::information',
#  'amenity::nightclub',
#  'amenity::drinking_water',
#  'amenity::parking_entrance',
#  'tourism::artwork',
#  'historic::aircraft',
#  'shop::vacant',
#  'historic::ruins',
#  'amenity::social_facility',
#  'shop::furniture',
#  'amenity::vehicle_inspection',
#  'leisure::marina',
#  'shop::dairy',
#  'amenity::car_wash',
#  'shop::alcohol',
#  'shop::sports',
#  'shop::hairdresser',
#  'shop::outpost',
#  'shop::mall',
#  'amenity::grave_yard',
#  'historic::cannon',
#  'shop::greengrocer',
#  'amenity::bicycle_parking',
#  'shop::butcher',
#  'shop::bakery',
#  'amenity::public_building',
#  'leisure::dog_park',
#  'craft::electronics_repair',
#  'amenity::fountain',
#  'amenity::arts_centre',
#  'shop::ticket',
#  'historic::castle',
#  'shop::florist',
#  'amenity::car_rental',
#  'tourism::hostel',
#  'shop::outdoor',
#  'shop::car',
#  'tourism::theme_park',
#  'historic::wayside_cross',
#  'place::quarter',
#  'amenity::veterinary',
#  'amenity::dentist',
#  'amenity::bureau_de_change',
#  'shop::beverages',
#  'shop::optician',
#  'amenity::fuel',
#  'leisure::fitness_centre',
#  'amenity::waste_disposal',
#  'shop::garden_centre',
#  'tourism::chalet',
#  'amenity::courthouse',
#  'leisure::sports_centre',
#  'amenity::shelter',
#  'leisure::playground',
#  'tourism::guest_house',
#  'tourism::picnic_site',
#  'leisure::water_park',
#  'amenity::bicycle_rental',
#  'amenity::boat_rental',
#  'office::employment_agency',
#  'leisure::stadium',
#  'shop::computer',
#  'shop::hardware',
#  'shop::shoes',
#  'amenity::townhall',
#  'tourism::camp_site',
#  'leisure::pitch',
#  'leisure::ice_rink',
#  'shop::toys',
#  'leisure::fishing',
#  'amenity::hunting_stand',
#  'shop::hifi',
#  'shop::chemist',
#  'amenity::bench',
#  'shop::tyres',
#  'historic::battlefield',
#  'building::yes',
#  'amenity::vending_machine',
#  'shop::jewelry',
#  'tourism::zoo',
#  'building::chapel',
#  'building::temple',
#  'amenity::taxi',
#  'historic::wayside_shrine',
#  'shop::baby_goods',
#  'shop::variety_store',
#  'shop::organic',
#  'healthcare::laboratory',
#  'shop::department_store',
#  'shop::party',
#  'amenity::stripclub',
#  'shop::stationery',
#  'building::cathedral',
#  'amenity::waste_basket',
#  'amenity::music_school',
#  'amenity::crematorium',
#  'shop::hunting',
#  'shop::newsagent',
#  'place::state',
#  'office::diplomatic',
#  'shop::spices',
#  'shop::pet',
#  'craft::photographer',
#  'shop::bathroom_furnishing',
#  'shop::curtain',
#  'office::notary',
#  'office::property_management',
#  'shop::houseware',
#  'amenity::grit_bin',
#  'shop::dry_cleaning',
#  'amenity::recycling',
#  'shop::pyrotechnics',
#  'office::company',
#  'shop::frame',
#  'shop::erotic',
#  'shop::tobacco',
#  'shop::pawnbroker',
#  'shop::fabric',
#  'shop::radiotechnics',
#  'amenity::food_court',
#  'craft::tailor',
#  'shop::medical_supply',
#  'office::lawyer',
#  'leisure::dance',
#  'shop::second_hand',
#  'historic::archaeological_site',
#  'building::kiosk',
#  'building::farm_auxiliary',
#  'shop::travel_agency',
#  'shop::funeral_directors',
#  'shop::farm',
#  'shop::ice_cream',
#  'shop::gift',
#  'shop::bookmaker',
#  'place::island',
#  'building::house',
#  'amenity::driving_school',
#  'shop::seafood',
#  'shop::religion',
#  'building::bunker',
#  'office::association',
#  'amenity::community_centre',
#  'shop::wholesale',
#  'tourism::gallery',
#  'office::research',
#  'shop::flooring',
#  'shop::laundry',
#  'craft::shoemaker',
#  'shop::tiles',
#  'shop::photo',
#  'office::estate_agent',
#  'shop::electrical',
#  'leisure::park',
#  'amenity::training',
#  'shop::confectionery',
#  'leisure::picnic_table',
#  'shop::motorcycle',
#  'building::dormitory',
#  'craft::photographic_laboratory',
#  'office::newspaper',
#  'building::service',
#  'historic::vehicle',
#  'shop::boutique',
#  'shop::massage',
#  'shop::video',
#  'building::garage',
#  'amenity::parking',
#  'amenity::studio',
#  'office::ngo',
#  'leisure::fitness_station',
#  'shop::bed',
#  'shop::music',
#  'office::administrative',
#  'shop::appliance',
#  'leisure::slipway',
#  'office::travel_agent',
#  'shop::fishing',
#  'historic::tomb',
#  'healthcare::blood_donation',
#  'healthcare::birthing_centre',
#  'amenity::prison',
#  'office::educational_institution',
#  'shop::tea',
#  'building::public',
#  'shop::musical_instrument',
#  'building::monastery',
#  'historic::milestone',
#  'craft::key_cutter',
#  'building::office',
#  'shop::kitchen',
#  'amenity::ice_cream',
#  'amenity::events_venue',
#  'historic::monastery',
#  'craft::window_construction',
#  'amenity::kindergarten',
#  'office::government',
#  'shop::coffee',
#  'shop::art',
#  'shop::tailor',
#  'shop::copyshop',
#  'office::advertising_agency',
#  'shop::interior_decoration',
#  'shop::glaziery',
#  'shop::general',
#  'historic::tank',
#  'office::architect',
#  'craft::jeweller',
#  'craft::electrician',
#  'building::residential',
#  'shop::deli',
#  'tourism::caravan_site',
#  'shop::bag',
#  'shop::sewing',
#  'shop::paint',
#  'leisure::track',
#  'shop::yes',
#  'shop::craft',
#  'healthcare::rehabilitation',
#  'building::apartments',
#  'shop::doors',
#  'craft::dressmaker',
#  'craft::metal_construction',
#  'amenity::animal_boarding',
#  'amenity::planetarium',
#  'amenity::internet_cafe',
#  'shop::lighting',
#  'tourism::yes',
#  'office::political_party',
#  'historic::yes',
#  'building::detached',
#  'office::it',
#  'craft::watchmaker',
#  'amenity::love_hotel',
#  'shop::antiques',
#  'shop::anime',
#  'craft::stonemason',
#  'amenity::bbq',
#  'amenity::public_bath',
#  'shop::weapons',
#  'shop::carpet',
#  'shop::hairdresser_supply',
#  'shop::trade',
#  'craft::hvac',
#  'building::entrance',
#  'shop::hearing_aids',
#  'amenity::baby_hatch',
#  'healthcare::psychotherapist',
#  'shop::money_lender',
#  'office::logistics',
#  'office::accountant',
#  'leisure::escape_game',
#  'leisure::summer_camp',
#  'shop::perfumery',
#  'shop::watches',
#  'building::hospital',
#  'shop::tattoo',
#  'leisure::garden',
#  'craft::painter',
#  'craft::sawmill',
#  'shop::water',
#  'shop::pet_grooming',
#  'amenity::shower',
#  'craft::clockmaker',
#  'shop::fashion',
#  'shop::scuba_diving',
#  'shop::window_blind',
#  'amenity::childcare',
#  'building::shed',
#  'leisure::nature_reserve',
#  'shop::camera',
#  'shop::vacuum_cleaner',
#  'shop::gas',
#  'shop::wine',
#  'craft::handicraft',
#  'tourism::aquarium',
#  'amenity::nursing_home',
#  'shop::locksmith',
#  'building::retail',
#  'building::train_station',
#  'craft::insulation',
#  'shop::health_food',
#  'building::warehouse',
#  'amenity::compressed_air',
#  'craft::caterer',
#  'leisure::horse_riding',
#  'amenity::biergarten',
#  'place::islet',
#  'office::foundation',
#  'amenity::water_point',
#  'shop::chocolate',
#  'leisure::swimming_pool',
#  'building::civic',
#  'amenity::school',
#  'building::school',
#  'building::commercial',
#  'leisure::beach_resort',
#  'building::garages',
#  'office::quango',
#  'historic::citywalls',
#  'building::greenhouse',
#  'amenity::university',
#  'healthcare::speech_therapist',
#  'shop::herbalist',
#  'building::hut',
#  'shop::cheese',
#  'craft::blacksmith',
#  'craft::beekeeper',
#  'shop::boat',
#  'shop::fireplace',
#  'amenity::parking_space',
#  'office::yes',
#  'building::ruins',
#  'amenity::brothel',
#  'leisure::firepit',
#  'shop::atv',
#  'shop::video_games',
#  'amenity::dive_centre',
#  'building::industrial',
#  'office::visa',
#  'building::roof',
#  'shop::leather',
#  'craft::brewery',
#  'shop::games',
#  'shop::pastry',
#  'tourism::apartment',
#  'amenity::public_bookcase',
#  'craft::tiler',
#  'historic::tower',
#  'building::construction',
#  'building::supermarket',
#  'craft::dental_technician',
#  'office::guide',
#  'shop::garden_furniture',
#  'shop::lottery',
#  'craft::toolmaker',
#  'leisure::bird_hide',
#  'historic::building',
#  'amenity::charging_station',
#  'leisure::swimming_area',
#  'craft::gardener',
#  'craft::carpenter',
#  'historic::stone',
#  'shop::model',
#  'shop::windows',
#  'shop::e-cigarette',
#  'leisure::common',
#  'office::financial',
#  'amenity::parcel_locker',
#  'amenity::ranger_station',
#  'office::therapist',
#  'amenity::animal_breeding',
#  'craft::plumber',
#  'craft::car_painter',
#  'amenity::motorcycle_parking',
#  'building::barn',
#  'building::kindergarten',
#  'craft::locksmith',
#  'amenity::gambling',
#  'building::stable',
#  'office::union',
#  'building::beach_hut',
#  'healthcare::alternative',
#  'shop::security',
#  'healthcare::optometrist',
#  'shop::lamps',
#  'amenity::waste_transfer_station',
#  'amenity::bicycle_repair_station',
#  'craft::confectionery',
#  'amenity::college',
#  'building::college',
#  'office::energy_supplier',
#  'shop::nutrition_supplements',
#  'craft::roofer',
#  'shop::energy',
#  'building::hangar',
#  'shop::swimming_pool',
#  'craft::upholsterer',
#  'office::water_utility',
#  'place::square',
#  'craft::tinsmith',
#  'amenity::photo_booth',
#  'craft::builder',
#  'craft::glaziery',
#  'office::tax_advisor',
#  'amenity::car_sharing',
#  'tourism::wilderness_hut',
#  'craft::scaffolder',
#  'leisure::amusement_arcade',
#  'building::cabin',
#  'building::toilets',
#  'amenity::animal_shelter',
#  'shop::brewing_supplies',
#  'amenity::hospital',
#  'historic::ship',
#  'historic::church',
#  'craft::bookbinder',
#  'building::bungalow',
#  'office::construction_company',
#  'office::courier',
#  'shop::storage_rental',
#  'amenity::casino',
#  'building::transformer_tower',
#  'leisure::hackerspace',
#  'office::consulting',
#  'building::silo',
#  'craft::pottery',
#  'historic::highwater_mark',
#  'office::surveyor',
#  'shop::candles',
#  'healthcare::podiatrist',
#  'office::coworking',
#  'building::storage_tank',
#  'building::sty',
#  'leisure::disc_golf_course',
#  'healthcare::yes',
#  'shop::agrarian',
#  'amenity::boat_sharing',
#  'amenity::monastery',
#  'amenity::dressing_room',
#  'office::charity',
#  'office::geodesist',
#  'historic::wreck',
#  'craft::basket_maker',
#  'office::insurance',
#  'amenity::watering_place',
#  'office::financial_advisor',
#  'shop::charity',
#  'healthcare::hospice',
#  'amenity::toilets',
#  'tourism::camp_pitch',
#  'craft::winery',
#  'craft::chimney_sweeper',
#  'amenity::social_centre',
#  'historic::bomb_crater',
#  'shop::fuel',
#  'craft::atelier',
#  'office::engineer',
#  'craft::parquet_layer',
#  'craft::joiner',
#  'craft::printmaker',
#  'craft::bakery',
#  'craft::sculptor',
#  'shop::frozen_food',
#  'place::plot',
#  'office::moving_company',
#  'craft::distillery',
#  'craft::engraver',
#  'healthcare::midwife',
#  'shop::military_surplus',
#  'amenity::post_depot',
#  'shop::household_linen',
#  'healthcare::physiotherapist',
#  'building::tree_house',
#  'healthcare::counselling',
#  'healthcare::vaccination_centre',
#  'shop::pest_control',
#  'office::graphic_design',
#  'shop::groundskeeping',
#  'amenity::lounger',
#  'amenity::give_box',
#  'craft::boatbuilder',
#  'healthcare::blood_bank',
#  'amenity::sanitary_dump_station',
#  'amenity::funeral_hall']

# %%
objs
# Out:
#        field_1                     type         lon         lat  \
# 0            0        shop::supermarket  37.2075319  55.9951147
# 1            1              place::city  35.9208284   56.858675
# 2            2              place::town  34.5720732  57.5883648
# 3            3              place::city  32.0461261  54.7814057
# 4            4              place::city  34.3668288  53.2423778
# ...        ...                      ...         ...         ...
# 416257  416257  amenity::drinking_water  36.8955369  54.9067184
# 416258  416258       amenity::telephone  36.9077863  54.9033208
# 416259  416259     tourism::information  36.8678973   54.911728
# 416260  416260       amenity::telephone  36.8678119  54.9117556
# 416261  416261       amenity::telephone  36.8490128  54.9194606
#
#                              geometry
# 0       POINT (37.2075319 55.9951147)
# 1        POINT (35.9208284 56.858675)
# 2       POINT (34.5720732 57.5883648)
# 3       POINT (32.0461261 54.7814057)
# 4       POINT (34.3668288 53.2423778)
# ...                               ...
# 416257  POINT (36.8955369 54.9067184)
# 416258  POINT (36.9077863 54.9033208)
# 416259   POINT (36.8678973 54.911728)
# 416260  POINT (36.8678119 54.9117556)
# 416261  POINT (36.8490128 54.9194606)
#
# [416262 rows x 5 columns]
