# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Polygon, Point
import geopy.distance
import geocoder
from tqdm import tqdm

# %%
df_train = pd.read_csv('train.csv', index_col=[0]).dropna()
df_test = pd.read_csv('test.csv', index_col=[0])

# %%
# concat_df = pd.concat([df_train,df_test])
concat_df = pd.read_csv('concat_df.csv')
concat_df.head()
# Out:
#    Unnamed: 0      id  atm_group                                 address  \
# 0           0  8526.0       32.0  EMELYANOVA,34          Y-SAKHALINSK
# 1           1  8532.0       32.0  KOMSOMOLSKAYA,259B     Y.SAKHALINSK
# 2           2  8533.0       32.0  KOMMUN. PR., 32        YUZHNO SAKHAL
# 3           3  8684.0       32.0  LENINGRADSKIY PR.,76A  MOSCOW
# 4           4    37.0       32.0  GVARDEYSKAYA PL., 2    NORILSK
#
#                                          address_rus        lat        long  \
# 0  улица А.О. Емельянова, 34, Южно-Сахалинск, Сах...  46.940995  142.738319
# 1  Комсомольская улица, 259, Южно-Сахалинск, Саха...  46.937353  142.753348
# 2  Коммунистический проспект, Южно-Сахалинск, Сах...  46.959413  142.741113
# 3  Ленинградский проспект, 76А, Москва, Россия, 1...  55.805827   37.515146
# 4  Гвардейская площадь, 2, Норильск, Красноярский...  69.343541   88.211228
#
#      target
# 0  0.011500
# 1  0.029710
# 2  0.009540
# 3 -0.094035
# 4  0.079277

# %%
# Список OSM тэгов
tag_list = [
    {'subway': ['yes']},
    {'public_transport': ['stop_position']},
    {'government': ['administrative']},
    {'amenity': ['college', 'university']},
    {'amenity': ['school']},
    {'amenity': ['kindergarten', 'childcare']},
    {'office': ['company']},
    {'amenity': ['cafe', 'fast_food', 'bar', 'pub', 'canteen']}
]

# Human-readable имена тегов 
tag_names = [
    'subway',
    'bus_stop',
    'gov_building',
    'college',
    'school',
    'kgarden',
    'office',
    'food'
]

# %%
import overpy
import time
api = overpy.Overpass()

def flatten(l):
    return [item for sublist in l for item in sublist]

def query(api,radius,lat,lon):
    try:
        result = api.query("""
    (
        node["subway"="yes"](around:{radius},{lat}, {lon});
        node["public_transport"="stop_position"](around:{radius},{lat}, {lon});
        node["government"="administrative"](around:{radius},{lat}, {lon});
        node["amenity"~"^(college|university)$"](around:{radius},{lat}, {lon});
        node["amenity"="school"](around:{radius},{lat}, {lon});
        node["amenity"~"^(kindergarten|childcare)$"](around:{radius},{lat}, {lon});
        node["office"="company"](around:{radius},{lat}, {lon});
        node["amenity"~"^(cafe|fast_food|bar|pub|canteen)$"](around:{radius},{lat}, {lon});
    );
    out body;
            """.format(radius=radius,lat=lat,lon=lon))
    except Exception as e:
        time.sleep(30)
        result = api.query("""
    (
        node["subway"="yes"](around:{radius},{lat}, {lon});
        node["public_transport"="stop_position"](around:{radius},{lat}, {lon});
        node["government"="administrative"](around:{radius},{lat}, {lon});
        node["amenity"~"^(college|university)$"](around:{radius},{lat}, {lon});
        node["amenity"="school"](around:{radius},{lat}, {lon});
        node["amenity"~"^(kindergarten|childcare)$"](around:{radius},{lat}, {lon});
        node["office"="company"](around:{radius},{lat}, {lon});
        node["amenity"~"^(cafe|fast_food|bar|pub|canteen)$"](around:{radius},{lat}, {lon});
    );
    out body;
            """.format(radius=radius,lat=lat,lon=lon))
    return result

# res = query(api,10000,55.805827,37.515146)

def find_tag(node):
    for i in range(len(tag_list)):
        if list(tag_list[i].keys())[0] in node.tags:
            if node.tags[list(tag_list[i].keys())[0]] in tag_list[i][list(tag_list[i].keys())[0]]:
                return tag_names[i]
    raise ValueError('tag not found ',node.tags)

def process_query(idx,api,lat,lon):
    res = query(api,10000,lat,lon)
    
    row = dict.fromkeys(flatten([*map(lambda x: [x+'_min_dist',x+'_250m',x+'_500m'],tag_names)]),0)
    row.update({'id':idx})
    for key in row:
        if '_min_dist' in key:
            row[key] = 10000
    for node in res.nodes:
        coords_1 = (lat,lon)
        coords_2 = (node.lat,node.lon)
        distance = geopy.distance.geodesic(coords_1, coords_2).m
        try:
            tag = find_tag(node)
        
            if(distance <= 250):
                row[tag+'_250m']+=1
            if(distance <= 500):
                row[tag+'_500m']+=1
            if(distance <row[tag+'_min_dist']):
                row[tag+'_min_dist'] = distance
        except ValueError:
            print(node.tags)
        
    return row

# %%
process_query('8684',api,55.805827,37.515146)
# Out:
# {'subway_min_dist': 59.371791355662175,
#  'subway_250m': 3,
#  'subway_500m': 3,
#  'bus_stop_min_dist': 60.155842572180674,
#  'bus_stop_250m': 2,
#  'bus_stop_500m': 12,
#  'gov_building_min_dist': 3743.08564566892,
#  'gov_building_250m': 0,
#  'gov_building_500m': 0,
#  'college_min_dist': 1280.980381544977,
#  'college_250m': 0,
#  'college_500m': 0,
#  'school_min_dist': 841.1426736863608,
#  'school_250m': 0,
#  'school_500m': 0,
#  'kgarden_min_dist': 105.7005905391319,
#  'kgarden_250m': 2,
#  'kgarden_500m': 3,
#  'office_min_dist': 112.12425770079038,
#  'office_250m': 2,
#  'office_500m': 9,
#  'food_min_dist': 5.6248526530663385,
#  'food_250m': 12,
#  'food_500m': 36,
#  'id': '8684'}

# %%
# rows = []

for index, row in tqdm(concat_df.iterrows(), total=concat_df.shape[0]):
    if row['id'] not in [*map(lambda x: x['id'],rows)]:
        row = process_query(row['id'],api,row['lat'],row['long'])
        rows.append(row)
# Out:
# 100%|███████████████████████████████████████| 8461/8461 [32:05<00:00,  4.39it/s]

# %%
adj_df = pd.DataFrame(rows)
adj_df.to_csv('adj_df.csv')
adj_df.head()
# Out:
#    subway_min_dist  subway_250m  subway_500m  bus_stop_min_dist  \
# 0     10000.000000            0            0         829.198383
# 1     10000.000000            0            0        1376.218766
# 2     10000.000000            0            0        1203.574630
# 3        59.371791            3            3          60.155843
# 4     10000.000000            0            0          57.913245
#
#    bus_stop_250m  bus_stop_500m  gov_building_min_dist  gov_building_250m  \
# 0              0              0           10000.000000                  0
# 1              0              0           10000.000000                  0
# 2              0              0           10000.000000                  0
# 3              2             12            3743.085646                  0
# 4              7             14           10000.000000                  0
#
#    gov_building_500m  college_min_dist  ...  kgarden_min_dist  kgarden_250m  \
# 0                  0      10000.000000  ...       1254.875056             0
# 1                  0      10000.000000  ...         79.966472             1
# 2                  0      10000.000000  ...        850.505033             0
# 3                  0       1280.980382  ...        105.700591             2
# 4                  0       1279.238327  ...       1093.540862             0
#
#    kgarden_500m  office_min_dist  office_250m  office_500m  food_min_dist  \
# 0             0      1086.833836            0            0     688.469156
# 1             1       732.490315            0            0     197.747969
# 2             0       526.584497            0            0     174.983219
# 3             3       112.124258            2            9       5.624853
# 4             0       119.987527            4            5     103.082008
#
#    food_250m  food_500m      id
# 0          0          0  8526.0
# 1          1          1  8532.0
# 2          2          7  8533.0
# 3         12         36  8684.0
# 4          3          7    37.0
#
# [5 rows x 25 columns]

# %%
adj_df
# Out:
#       subway_min_dist  subway_250m  subway_500m  bus_stop_min_dist  \
# 0        10000.000000            0            0         829.198383
# 1        10000.000000            0            0        1376.218766
# 2        10000.000000            0            0        1203.574630
# 3           59.371791            3            3          60.155843
# 4        10000.000000            0            0          57.913245
# ...               ...          ...          ...                ...
# 8456     10000.000000            0            0         363.699181
# 8457     10000.000000            0            0         666.129410
# 8458     10000.000000            0            0          31.505167
# 8459     10000.000000            0            0         822.801779
# 8460     10000.000000            0            0         140.209270
#
#       bus_stop_250m  bus_stop_500m  gov_building_min_dist  gov_building_250m  \
# 0                 0              0           10000.000000                  0
# 1                 0              0           10000.000000                  0
# 2                 0              0           10000.000000                  0
# 3                 2             12            3743.085646                  0
# 4                 7             14           10000.000000                  0
# ...             ...            ...                    ...                ...
# 8456              0              3            6928.489571                  0
# 8457              0              0            6504.445618                  0
# 8458              8              9            3148.939027                  0
# 8459              0              0           10000.000000                  0
# 8460              2             14           10000.000000                  0
#
#       gov_building_500m  college_min_dist  ...  kgarden_min_dist  \
# 0                     0      10000.000000  ...       1254.875056
# 1                     0      10000.000000  ...         79.966472
# 2                     0      10000.000000  ...        850.505033
# 3                     0       1280.980382  ...        105.700591
# 4                     0       1279.238327  ...       1093.540862
# ...                 ...               ...  ...               ...
# 8456                  0       1979.172678  ...       2508.324696
# 8457                  0       4452.938422  ...       3101.956893
# 8458                  0        803.748157  ...        494.980690
# 8459                  0       3539.252622  ...       3486.211164
# 8460                  0        699.687145  ...        606.256596
#
#       kgarden_250m  kgarden_500m  office_min_dist  office_250m  office_500m  \
# 0                0             0      1086.833836            0            0
# 1                1             1       732.490315            0            0
# 2                0             0       526.584497            0            0
# 3                2             3       112.124258            2            9
# 4                0             0       119.987527            4            5
# ...            ...           ...              ...          ...          ...
# 8456             0             0       662.235480            0            0
# 8457             0             0      1127.837214            0            0
# 8458             0             1       273.810838            0            1
# 8459             0             0       169.837228            1            2
# 8460             0             0       449.786314            0            1
#
#       food_min_dist  food_250m  food_500m      id
# 0        688.469156          0          0  8526.0
# 1        197.747969          1          1  8532.0
# 2        174.983219          2          7  8533.0
# 3          5.624853         12         36  8684.0
# 4        103.082008          3          7    37.0
# ...             ...        ...        ...     ...
# 8456     635.152036          0          0  3199.0
# 8457    2899.964963          0          0  5354.0
# 8458     106.815903          4          7  3333.0
# 8459     600.168287          0          0  2247.0
# 8460     168.194002          2         25  5347.0
#
# [8461 rows x 25 columns]

# %%
rows = [*filter(lambda row: row['id'] not in adj_df[adj_df.id.isin(concat_df[concat_df.lat.isna()].id)].id.to_list(),rows)]

# %%
# Out:
# [{'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 829.1983827178741,
#   'bus_stop_250m': 0,
#   'bus_stop_500m': 0,
#   'gov_building_min_dist': 10000,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 10000,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 533.866601995004,
#   'school_250m': 0,
#   'school_500m': 0,
#   'kgarden_min_dist': 1254.8750563032816,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 1086.833836204933,
#   'office_250m': 0,
#   'office_500m': 0,
#   'food_min_dist': 688.4691556573313,
#   'food_250m': 0,
#   'food_500m': 0,
#   'id': 8526.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 1376.2187659440651,
#   'bus_stop_250m': 0,
#   'bus_stop_500m': 0,
#   'gov_building_min_dist': 10000,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 10000,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 1359.2987334757202,
#   'school_250m': 0,
#   'school_500m': 0,
#   'kgarden_min_dist': 79.96647176966374,
#   'kgarden_250m': 1,
#   'kgarden_500m': 1,
#   'office_min_dist': 732.4903152162667,
#   'office_250m': 0,
#   'office_500m': 0,
#   'food_min_dist': 197.74796929097812,
#   'food_250m': 1,
#   'food_500m': 1,
#   'id': 8532.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 1203.5746298809865,
#   'bus_stop_250m': 0,
#   'bus_stop_500m': 0,
#   'gov_building_min_dist': 10000,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 10000,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 733.6749475974974,
#   'school_250m': 0,
#   'school_500m': 0,
#   'kgarden_min_dist': 850.5050328961305,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 526.5844971575312,
#   'office_250m': 0,
#   'office_500m': 0,
#   'food_min_dist': 174.98321861605868,
#   'food_250m': 2,
#   'food_500m': 7,
#   'id': 8533.0},
#  {'subway_min_dist': 59.371791355662175,
#   'subway_250m': 3,
#   'subway_500m': 3,
#   'bus_stop_min_dist': 60.155842572180674,
#   'bus_stop_250m': 2,
#   'bus_stop_500m': 12,
#   'gov_building_min_dist': 3743.08564566892,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 1280.980381544977,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 841.1426736863608,
#   'school_250m': 0,
#   'school_500m': 0,
#   'kgarden_min_dist': 105.7005905391319,
#   'kgarden_250m': 2,
#   'kgarden_500m': 3,
#   'office_min_dist': 112.12425770079038,
#   'office_250m': 2,
#   'office_500m': 9,
#   'food_min_dist': 5.6248526530663385,
#   'food_250m': 12,
#   'food_500m': 36,
#   'id': 8684.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 57.91324516400047,
#   'bus_stop_250m': 7,
#   'bus_stop_500m': 14,
#   'gov_building_min_dist': 10000,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 1279.2383267392731,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 346.0182383277814,
#   'school_250m': 0,
#   'school_500m': 1,
#   'kgarden_min_dist': 1093.5408621175766,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 119.98752710690644,
#   'office_250m': 4,
#   'office_500m': 5,
#   'food_min_dist': 103.08200818844377,
#   'food_250m': 3,
#   'food_500m': 7,
#   'id': 37.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 36.6564484988706,
#   'bus_stop_250m': 3,
#   'bus_stop_500m': 12,
#   'gov_building_min_dist': 7819.238403427225,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 1664.675145323276,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 447.0315432920952,
#   'school_250m': 0,
#   'school_500m': 1,
#   'kgarden_min_dist': 1174.1860484747062,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 193.79513276763416,
#   'office_250m': 1,
#   'office_500m': 1,
#   'food_min_dist': 54.09426421487449,
#   'food_250m': 4,
#   'food_500m': 12,
#   'id': 313.0},
#  {'subway_min_dist': 476.34059989930535,
#   'subway_250m': 0,
#   'subway_500m': 3,
#   'bus_stop_min_dist': 302.9524275918419,
#   'bus_stop_250m': 0,
#   'bus_stop_500m': 8,
#   'gov_building_min_dist': 3689.8530438144107,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 346.0617575167646,
#   'college_250m': 0,
#   'college_500m': 1,
#   'school_min_dist': 1074.4206409375943,
#   'school_250m': 0,
#   'school_500m': 0,
#   'kgarden_min_dist': 638.9181316164699,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 245.17363874818878,
#   'office_250m': 1,
#   'office_500m': 2,
#   'food_min_dist': 95.85771401436983,
#   'food_250m': 2,
#   'food_500m': 17,
#   'id': 335.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 70.21732550062431,
#   'bus_stop_250m': 7,
#   'bus_stop_500m': 10,
#   'gov_building_min_dist': 2257.6572532762134,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 337.1915747408199,
#   'college_250m': 0,
#   'college_500m': 1,
#   'school_min_dist': 268.7571525601517,
#   'school_250m': 0,
#   'school_500m': 2,
#   'kgarden_min_dist': 409.00584178122614,
#   'kgarden_250m': 0,
#   'kgarden_500m': 2,
#   'office_min_dist': 278.65421407798874,
#   'office_250m': 0,
#   'office_500m': 3,
#   'food_min_dist': 31.989782563249303,
#   'food_250m': 22,
#   'food_500m': 73,
#   'id': 358.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 3432.6126327175184,
#   'bus_stop_250m': 0,
#   'bus_stop_500m': 0,
#   'gov_building_min_dist': 9780.344613257977,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 10000,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 5244.971735581259,
#   'school_250m': 0,
#   'school_500m': 0,
#   'kgarden_min_dist': 4532.553635154788,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 2069.5400582164484,
#   'office_250m': 0,
#   'office_500m': 0,
#   'food_min_dist': 1244.2262135648286,
#   'food_250m': 0,
#   'food_500m': 0,
#   'id': 2895.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 2195.6262491054094,
#   'bus_stop_250m': 0,
#   'bus_stop_500m': 0,
#   'gov_building_min_dist': 10000,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 3752.424548130876,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 1680.5675874080973,
#   'school_250m': 0,
#   'school_500m': 0,
#   'kgarden_min_dist': 677.4683567661057,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 233.24120310794004,
#   'office_250m': 2,
#   'office_500m': 7,
#   'food_min_dist': 367.3086572717933,
#   'food_250m': 0,
#   'food_500m': 1,
#   'id': 1975.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 61.144033067474666,
#   'bus_stop_250m': 4,
#   'bus_stop_500m': 13,
#   'gov_building_min_dist': 10000,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 297.0369921786803,
#   'college_250m': 0,
#   'college_500m': 3,
#   'school_min_dist': 3431.202674674775,
#   'school_250m': 0,
#   'school_500m': 0,
#   'kgarden_min_dist': 1568.468464332436,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 110.49015975941074,
#   'office_250m': 4,
#   'office_500m': 11,
#   'food_min_dist': 5.213542078047793,
#   'food_250m': 11,
#   'food_500m': 16,
#   'id': 1977.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 242.96416700386655,
#   'bus_stop_250m': 1,
#   'bus_stop_500m': 7,
#   'gov_building_min_dist': 10000,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 392.7058364817843,
#   'college_250m': 0,
#   'college_500m': 1,
#   'school_min_dist': 489.28158508204837,
#   'school_250m': 0,
#   'school_500m': 1,
#   'kgarden_min_dist': 330.39048109320254,
#   'kgarden_250m': 0,
#   'kgarden_500m': 1,
#   'office_min_dist': 596.7386551551655,
#   'office_250m': 0,
#   'office_500m': 0,
#   'food_min_dist': 187.1955112175765,
#   'food_250m': 1,
#   'food_500m': 14,
#   'id': 1992.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 10000,
#   'bus_stop_250m': 0,
#   'bus_stop_500m': 0,
#   'gov_building_min_dist': 10000,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 3606.9133329818246,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 1025.6912977621434,
#   'school_250m': 0,
#   'school_500m': 0,
#   'kgarden_min_dist': 1064.4459408202617,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 158.6015767249861,
#   'office_250m': 1,
#   'office_500m': 2,
#   'food_min_dist': 202.65020671429005,
#   'food_250m': 1,
#   'food_500m': 5,
#   'id': 1998.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 23.553207334962313,
#   'bus_stop_250m': 2,
#   'bus_stop_500m': 2,
#   'gov_building_min_dist': 10000,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 10000,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 453.49620216349706,
#   'school_250m': 0,
#   'school_500m': 1,
#   'kgarden_min_dist': 422.3616451616452,
#   'kgarden_250m': 0,
#   'kgarden_500m': 1,
#   'office_min_dist': 291.32032625367805,
#   'office_250m': 0,
#   'office_500m': 6,
#   'food_min_dist': 107.59170960586088,
#   'food_250m': 12,
#   'food_500m': 23,
#   'id': 2006.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 470.4793269050339,
#   'bus_stop_250m': 0,
#   'bus_stop_500m': 2,
#   'gov_building_min_dist': 10000,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 614.6204065400176,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 796.1777432247299,
#   'school_250m': 0,
#   'school_500m': 0,
#   'kgarden_min_dist': 234.83390194969837,
#   'kgarden_250m': 1,
#   'kgarden_500m': 1,
#   'office_min_dist': 321.78333833165243,
#   'office_250m': 0,
#   'office_500m': 1,
#   'food_min_dist': 361.24066893679407,
#   'food_250m': 0,
#   'food_500m': 1,
#   'id': 2011.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 10000,
#   'bus_stop_250m': 0,
#   'bus_stop_500m': 0,
#   'gov_building_min_dist': 10000,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 10000,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 10000,
#   'school_250m': 0,
#   'school_500m': 0,
#   'kgarden_min_dist': 10000,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 8940.561468561838,
#   'office_250m': 0,
#   'office_500m': 0,
#   'food_min_dist': 678.5753900434298,
#   'food_250m': 0,
#   'food_500m': 0,
#   'id': 2012.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 10000,
#   'bus_stop_250m': 0,
#   'bus_stop_500m': 0,
#   'gov_building_min_dist': 10000,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 10000,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 10000,
#   'school_250m': 0,
#   'school_500m': 0,
#   'kgarden_min_dist': 10000,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 10000,
#   'office_250m': 0,
#   'office_500m': 0,
#   'food_min_dist': 10000,
#   'food_250m': 0,
#   'food_500m': 0,
#   'id': 2017.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 146.98023943235643,
#   'bus_stop_250m': 2,
#   'bus_stop_500m': 2,
#   'gov_building_min_dist': 10000,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 10000,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 211.76733062025428,
#   'school_250m': 1,
#   'school_500m': 1,
#   'kgarden_min_dist': 356.41263847446095,
#   'kgarden_250m': 0,
#   'kgarden_500m': 1,
#   'office_min_dist': 8866.251676570992,
#   'office_250m': 0,
#   'office_500m': 0,
#   'food_min_dist': 145.5887155089896,
#   'food_250m': 2,
#   'food_500m': 2,
#   'id': 2022.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 131.24548790554766,
#   'bus_stop_250m': 2,
#   'bus_stop_500m': 2,
#   'gov_building_min_dist': 10000,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 6554.278262320339,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 4785.279211419722,
#   'school_250m': 0,
#   'school_500m': 0,
#   'kgarden_min_dist': 8175.2774369375875,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 5990.840569102581,
#   'office_250m': 0,
#   'office_500m': 0,
#   'food_min_dist': 591.517404929635,
#   'food_250m': 0,
#   'food_500m': 0,
#   'id': 2023.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 10000,
#   'bus_stop_250m': 0,
#   'bus_stop_500m': 0,
#   'gov_building_min_dist': 10000,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 10000,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 10000,
#   'school_250m': 0,
#   'school_500m': 0,
#   'kgarden_min_dist': 10000,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 10000,
#   'office_250m': 0,
#   'office_500m': 0,
#   'food_min_dist': 7176.8989434164705,
#   'food_250m': 0,
#   'food_500m': 0,
#   'id': 2027.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 311.9789452080096,
#   'bus_stop_250m': 0,
#   'bus_stop_500m': 1,
#   'gov_building_min_dist': 9713.019327857626,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 5152.966693422862,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 473.80480833169185,
#   'school_250m': 0,
#   'school_500m': 1,
#   'kgarden_min_dist': 2173.773432179569,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 231.7657388246341,
#   'office_250m': 1,
#   'office_500m': 1,
#   'food_min_dist': 17.878025852489507,
#   'food_250m': 9,
#   'food_500m': 13,
#   'id': 2033.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 139.65485054419332,
#   'bus_stop_250m': 2,
#   'bus_stop_500m': 5,
#   'gov_building_min_dist': 10000,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 658.3888744747707,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 2258.343101046277,
#   'school_250m': 0,
#   'school_500m': 0,
#   'kgarden_min_dist': 284.13622365631,
#   'kgarden_250m': 0,
#   'kgarden_500m': 4,
#   'office_min_dist': 1849.454270553694,
#   'office_250m': 0,
#   'office_500m': 0,
#   'food_min_dist': 348.84061783417866,
#   'food_250m': 0,
#   'food_500m': 3,
#   'id': 2034.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 2736.919017271343,
#   'bus_stop_250m': 0,
#   'bus_stop_500m': 0,
#   'gov_building_min_dist': 10000,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 602.6092780329955,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 3984.0021819730673,
#   'school_250m': 0,
#   'school_500m': 0,
#   'kgarden_min_dist': 3961.0299764744223,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 830.1450261932762,
#   'office_250m': 0,
#   'office_500m': 0,
#   'food_min_dist': 810.9883911182683,
#   'food_250m': 0,
#   'food_500m': 0,
#   'id': 2035.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 5502.508095910537,
#   'bus_stop_250m': 0,
#   'bus_stop_500m': 0,
#   'gov_building_min_dist': 1439.5173474784046,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 587.4734287310926,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 508.93469463262886,
#   'school_250m': 0,
#   'school_500m': 0,
#   'kgarden_min_dist': 1731.184376340833,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 408.78204733467777,
#   'office_250m': 0,
#   'office_500m': 1,
#   'food_min_dist': 61.97459411872511,
#   'food_250m': 2,
#   'food_500m': 2,
#   'id': 2850.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 61.26935864284706,
#   'bus_stop_250m': 2,
#   'bus_stop_500m': 6,
#   'gov_building_min_dist': 10000,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 1888.6143818697656,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 1247.0621159840514,
#   'school_250m': 0,
#   'school_500m': 0,
#   'kgarden_min_dist': 909.5669178452092,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 1093.816970741991,
#   'office_250m': 0,
#   'office_500m': 0,
#   'food_min_dist': 488.0445538376883,
#   'food_250m': 0,
#   'food_500m': 1,
#   'id': 2873.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 1196.8692942658095,
#   'bus_stop_250m': 0,
#   'bus_stop_500m': 0,
#   'gov_building_min_dist': 10000,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 577.1473167307179,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 1051.6827339561273,
#   'school_250m': 0,
#   'school_500m': 0,
#   'kgarden_min_dist': 1377.9479065780272,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 125.8539817772319,
#   'office_250m': 1,
#   'office_500m': 1,
#   'food_min_dist': 17.18047080671949,
#   'food_250m': 3,
#   'food_500m': 8,
#   'id': 2876.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 311.70327291484676,
#   'bus_stop_250m': 0,
#   'bus_stop_500m': 2,
#   'gov_building_min_dist': 10000,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 10000,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 10000,
#   'school_250m': 0,
#   'school_500m': 0,
#   'kgarden_min_dist': 10000,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 10000,
#   'office_250m': 0,
#   'office_500m': 0,
#   'food_min_dist': 1902.0341009586618,
#   'food_250m': 0,
#   'food_500m': 0,
#   'id': 2877.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 1293.1381727367495,
#   'bus_stop_250m': 0,
#   'bus_stop_500m': 0,
#   'gov_building_min_dist': 10000,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 950.2013504407696,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 1296.086949225634,
#   'school_250m': 0,
#   'school_500m': 0,
#   'kgarden_min_dist': 5185.79495578692,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 10000,
#   'office_250m': 0,
#   'office_500m': 0,
#   'food_min_dist': 431.94544027029434,
#   'food_250m': 0,
#   'food_500m': 2,
#   'id': 2897.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 827.9784173213503,
#   'bus_stop_250m': 0,
#   'bus_stop_500m': 0,
#   'gov_building_min_dist': 10000,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 10000,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 10000,
#   'school_250m': 0,
#   'school_500m': 0,
#   'kgarden_min_dist': 10000,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 10000,
#   'office_250m': 0,
#   'office_500m': 0,
#   'food_min_dist': 509.07725954389696,
#   'food_250m': 0,
#   'food_500m': 0,
#   'id': 2900.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 638.5387875030759,
#   'bus_stop_250m': 0,
#   'bus_stop_500m': 0,
#   'gov_building_min_dist': 10000,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 10000,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 443.9128010157494,
#   'school_250m': 0,
#   'school_500m': 1,
#   'kgarden_min_dist': 10000,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 326.63844663604567,
#   'office_250m': 0,
#   'office_500m': 2,
#   'food_min_dist': 85.79176259578173,
#   'food_250m': 4,
#   'food_500m': 9,
#   'id': 2914.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 1082.251494570978,
#   'bus_stop_250m': 0,
#   'bus_stop_500m': 0,
#   'gov_building_min_dist': 10000,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 2790.694811522553,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 2699.584648691811,
#   'school_250m': 0,
#   'school_500m': 0,
#   'kgarden_min_dist': 2286.58077556812,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 1672.1464946802676,
#   'office_250m': 0,
#   'office_500m': 0,
#   'food_min_dist': 1238.0139407486126,
#   'food_250m': 0,
#   'food_500m': 0,
#   'id': 2923.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 1814.6277417248027,
#   'bus_stop_250m': 0,
#   'bus_stop_500m': 0,
#   'gov_building_min_dist': 10000,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 1409.6634086089182,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 2079.8688827748547,
#   'school_250m': 0,
#   'school_500m': 0,
#   'kgarden_min_dist': 2991.507425245677,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 1451.3871118341374,
#   'office_250m': 0,
#   'office_500m': 0,
#   'food_min_dist': 117.51264120686565,
#   'food_250m': 2,
#   'food_500m': 2,
#   'id': 2951.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 8716.692918876333,
#   'bus_stop_250m': 0,
#   'bus_stop_500m': 0,
#   'gov_building_min_dist': 10000,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 10000,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 10000,
#   'school_250m': 0,
#   'school_500m': 0,
#   'kgarden_min_dist': 10000,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 842.995848448046,
#   'office_250m': 0,
#   'office_500m': 0,
#   'food_min_dist': 2818.351707330399,
#   'food_250m': 0,
#   'food_500m': 0,
#   'id': 2973.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 3016.5009851553214,
#   'bus_stop_250m': 0,
#   'bus_stop_500m': 0,
#   'gov_building_min_dist': 10000,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 10000,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 10000,
#   'school_250m': 0,
#   'school_500m': 0,
#   'kgarden_min_dist': 2710.8423375568427,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 10000,
#   'office_250m': 0,
#   'office_500m': 0,
#   'food_min_dist': 123.10407036666534,
#   'food_250m': 1,
#   'food_500m': 3,
#   'id': 4446.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 1451.0343026489647,
#   'bus_stop_250m': 0,
#   'bus_stop_500m': 0,
#   'gov_building_min_dist': 10000,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 10000,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 10000,
#   'school_250m': 0,
#   'school_500m': 0,
#   'kgarden_min_dist': 344.81475222166597,
#   'kgarden_250m': 0,
#   'kgarden_500m': 1,
#   'office_min_dist': 10000,
#   'office_250m': 0,
#   'office_500m': 0,
#   'food_min_dist': 187.59520565441662,
#   'food_250m': 1,
#   'food_500m': 1,
#   'id': 4447.0},
#  {'subway_min_dist': 132.3543925691195,
#   'subway_250m': 2,
#   'subway_500m': 2,
#   'bus_stop_min_dist': 1028.2535069326584,
#   'bus_stop_250m': 0,
#   'bus_stop_500m': 0,
#   'gov_building_min_dist': 3838.2757272883673,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 2751.6226267699685,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 1415.0810870898622,
#   'school_250m': 0,
#   'school_500m': 0,
#   'kgarden_min_dist': 2098.8310813238877,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 884.1288754178189,
#   'office_250m': 0,
#   'office_500m': 0,
#   'food_min_dist': 142.5674579532587,
#   'food_250m': 3,
#   'food_500m': 4,
#   'id': 4458.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 178.04277020433196,
#   'bus_stop_250m': 2,
#   'bus_stop_500m': 5,
#   'gov_building_min_dist': 10000,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 892.7162626286109,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 2043.765563131298,
#   'school_250m': 0,
#   'school_500m': 0,
#   'kgarden_min_dist': 2455.268656702499,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 651.4945383016461,
#   'office_250m': 0,
#   'office_500m': 0,
#   'food_min_dist': 359.5335587393296,
#   'food_250m': 0,
#   'food_500m': 3,
#   'id': 4466.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 10000,
#   'bus_stop_250m': 0,
#   'bus_stop_500m': 0,
#   'gov_building_min_dist': 10000,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 10000,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 10000,
#   'school_250m': 0,
#   'school_500m': 0,
#   'kgarden_min_dist': 10000,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 3188.162756035893,
#   'office_250m': 0,
#   'office_500m': 0,
#   'food_min_dist': 497.49750407970146,
#   'food_250m': 0,
#   'food_500m': 1,
#   'id': 4470.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 10000,
#   'bus_stop_250m': 0,
#   'bus_stop_500m': 0,
#   'gov_building_min_dist': 10000,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 10000,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 10000,
#   'school_250m': 0,
#   'school_500m': 0,
#   'kgarden_min_dist': 10000,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 10000,
#   'office_250m': 0,
#   'office_500m': 0,
#   'food_min_dist': 8778.858470513927,
#   'food_250m': 0,
#   'food_500m': 0,
#   'id': 4489.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 117.64642501829495,
#   'bus_stop_250m': 2,
#   'bus_stop_500m': 18,
#   'gov_building_min_dist': 10000,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 6390.062613424955,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 5530.671110463342,
#   'school_250m': 0,
#   'school_500m': 0,
#   'kgarden_min_dist': 4620.760000925757,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 295.96384177102027,
#   'office_250m': 0,
#   'office_500m': 1,
#   'food_min_dist': 184.45243322385554,
#   'food_250m': 2,
#   'food_500m': 4,
#   'id': 4491.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 2094.9393255334694,
#   'bus_stop_250m': 0,
#   'bus_stop_500m': 0,
#   'gov_building_min_dist': 10000,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 10000,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 10000,
#   'school_250m': 0,
#   'school_500m': 0,
#   'kgarden_min_dist': 10000,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 2111.7035514168274,
#   'office_250m': 0,
#   'office_500m': 0,
#   'food_min_dist': 89.8790862136515,
#   'food_250m': 1,
#   'food_500m': 1,
#   'id': 4511.0},
#  {'subway_min_dist': 6044.563152972485,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 1597.1924473533825,
#   'bus_stop_250m': 0,
#   'bus_stop_500m': 0,
#   'gov_building_min_dist': 10000,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 7365.724812810576,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 5273.746786410814,
#   'school_250m': 0,
#   'school_500m': 0,
#   'kgarden_min_dist': 2610.911786896135,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 628.4250397301763,
#   'office_250m': 0,
#   'office_500m': 0,
#   'food_min_dist': 380.60151134398393,
#   'food_250m': 0,
#   'food_500m': 1,
#   'id': 4512.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 29.032057749618136,
#   'bus_stop_250m': 1,
#   'bus_stop_500m': 5,
#   'gov_building_min_dist': 10000,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 4253.156085033044,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 2081.168875462483,
#   'school_250m': 0,
#   'school_500m': 0,
#   'kgarden_min_dist': 8227.446155688229,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 727.926489163072,
#   'office_250m': 0,
#   'office_500m': 0,
#   'food_min_dist': 264.57369671208613,
#   'food_250m': 0,
#   'food_500m': 2,
#   'id': 4523.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 119.86286806782502,
#   'bus_stop_250m': 3,
#   'bus_stop_500m': 8,
#   'gov_building_min_dist': 5878.117090194831,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 1043.6828359131248,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 290.94404021049354,
#   'school_250m': 0,
#   'school_500m': 1,
#   'kgarden_min_dist': 1054.555784567449,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 196.08349383396404,
#   'office_250m': 1,
#   'office_500m': 3,
#   'food_min_dist': 134.81428681730404,
#   'food_250m': 6,
#   'food_500m': 9,
#   'id': 4526.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 67.5669849695787,
#   'bus_stop_250m': 3,
#   'bus_stop_500m': 8,
#   'gov_building_min_dist': 10000,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 10000,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 546.5045486289753,
#   'school_250m': 0,
#   'school_500m': 0,
#   'kgarden_min_dist': 1012.0654852801591,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 233.82312517299988,
#   'office_250m': 1,
#   'office_500m': 2,
#   'food_min_dist': 35.2589006285288,
#   'food_250m': 1,
#   'food_500m': 2,
#   'id': 4542.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 275.46526124735965,
#   'bus_stop_250m': 0,
#   'bus_stop_500m': 4,
#   'gov_building_min_dist': 4047.5811084863185,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 405.80534261256867,
#   'college_250m': 0,
#   'college_500m': 1,
#   'school_min_dist': 463.9699675437281,
#   'school_250m': 0,
#   'school_500m': 1,
#   'kgarden_min_dist': 1390.4668873704009,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 1607.5098170146891,
#   'office_250m': 0,
#   'office_500m': 0,
#   'food_min_dist': 20.88033082779909,
#   'food_250m': 7,
#   'food_500m': 11,
#   'id': 4574.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 10000,
#   'bus_stop_250m': 0,
#   'bus_stop_500m': 0,
#   'gov_building_min_dist': 10000,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 10000,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 10000,
#   'school_250m': 0,
#   'school_500m': 0,
#   'kgarden_min_dist': 10000,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 10000,
#   'office_250m': 0,
#   'office_500m': 0,
#   'food_min_dist': 10000,
#   'food_250m': 0,
#   'food_500m': 0,
#   'id': 4584.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 1529.05114989002,
#   'bus_stop_250m': 0,
#   'bus_stop_500m': 0,
#   'gov_building_min_dist': 10000,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 5623.4681123333585,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 2923.202899875591,
#   'school_250m': 0,
#   'school_500m': 0,
#   'kgarden_min_dist': 993.4894165064159,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 2023.2494858096768,
#   'office_250m': 0,
#   'office_500m': 0,
#   'food_min_dist': 619.7695262783178,
#   'food_250m': 0,
#   'food_500m': 0,
#   'id': 4586.0},
#  {'subway_min_dist': 5369.862484481232,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 2534.5818841439404,
#   'bus_stop_250m': 0,
#   'bus_stop_500m': 0,
#   'gov_building_min_dist': 10000,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 5660.468179408558,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 4438.410046627781,
#   'school_250m': 0,
#   'school_500m': 0,
#   'kgarden_min_dist': 893.0217317182288,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 1664.7805620650772,
#   'office_250m': 0,
#   'office_500m': 0,
#   'food_min_dist': 124.07854824918765,
#   'food_250m': 2,
#   'food_500m': 2,
#   'id': 4588.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 1431.4111407715445,
#   'bus_stop_250m': 0,
#   'bus_stop_500m': 0,
#   'gov_building_min_dist': 10000,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 484.90706620613463,
#   'college_250m': 0,
#   'college_500m': 1,
#   'school_min_dist': 290.18506314749516,
#   'school_250m': 0,
#   'school_500m': 1,
#   'kgarden_min_dist': 10000,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 209.22892692371116,
#   'office_250m': 1,
#   'office_500m': 3,
#   'food_min_dist': 134.1866135968217,
#   'food_250m': 6,
#   'food_500m': 10,
#   'id': 4594.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 3081.1131190563424,
#   'bus_stop_250m': 0,
#   'bus_stop_500m': 0,
#   'gov_building_min_dist': 10000,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 10000,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 2096.0783103189838,
#   'school_250m': 0,
#   'school_500m': 0,
#   'kgarden_min_dist': 3404.93212496152,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 792.1592869227946,
#   'office_250m': 0,
#   'office_500m': 0,
#   'food_min_dist': 942.2297294478622,
#   'food_250m': 0,
#   'food_500m': 0,
#   'id': 4606.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 10000,
#   'bus_stop_250m': 0,
#   'bus_stop_500m': 0,
#   'gov_building_min_dist': 10000,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 10000,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 10000,
#   'school_250m': 0,
#   'school_500m': 0,
#   'kgarden_min_dist': 10000,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 10000,
#   'office_250m': 0,
#   'office_500m': 0,
#   'food_min_dist': 10000,
#   'food_250m': 0,
#   'food_500m': 0,
#   'id': 4608.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 683.1434371584505,
#   'bus_stop_250m': 0,
#   'bus_stop_500m': 0,
#   'gov_building_min_dist': 10000,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 10000,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 10000,
#   'school_250m': 0,
#   'school_500m': 0,
#   'kgarden_min_dist': 10000,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 10000,
#   'office_250m': 0,
#   'office_500m': 0,
#   'food_min_dist': 617.488540848439,
#   'food_250m': 0,
#   'food_500m': 0,
#   'id': 4624.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 631.7702366894905,
#   'bus_stop_250m': 0,
#   'bus_stop_500m': 0,
#   'gov_building_min_dist': 10000,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 10000,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 374.6987008286639,
#   'school_250m': 0,
#   'school_500m': 2,
#   'kgarden_min_dist': 10000,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 1851.0353863423197,
#   'office_250m': 0,
#   'office_500m': 0,
#   'food_min_dist': 359.0073408809384,
#   'food_250m': 0,
#   'food_500m': 4,
#   'id': 4649.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 973.8911915803341,
#   'bus_stop_250m': 0,
#   'bus_stop_500m': 0,
#   'gov_building_min_dist': 10000,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 10000,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 876.2750707889545,
#   'school_250m': 0,
#   'school_500m': 0,
#   'kgarden_min_dist': 10000,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 739.7529931576396,
#   'office_250m': 0,
#   'office_500m': 0,
#   'food_min_dist': 58.86105450277081,
#   'food_250m': 2,
#   'food_500m': 3,
#   'id': 4655.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 1016.7020464496384,
#   'bus_stop_250m': 0,
#   'bus_stop_500m': 0,
#   'gov_building_min_dist': 10000,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 1588.9441114309807,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 2372.3424868254533,
#   'school_250m': 0,
#   'school_500m': 0,
#   'kgarden_min_dist': 2632.176646812214,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 2710.122559376102,
#   'office_250m': 0,
#   'office_500m': 0,
#   'food_min_dist': 466.6412990242655,
#   'food_250m': 0,
#   'food_500m': 1,
#   'id': 4680.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 10000,
#   'bus_stop_250m': 0,
#   'bus_stop_500m': 0,
#   'gov_building_min_dist': 10000,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 10000,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 1036.7658467938652,
#   'school_250m': 0,
#   'school_500m': 0,
#   'kgarden_min_dist': 10000,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 10000,
#   'office_250m': 0,
#   'office_500m': 0,
#   'food_min_dist': 10000,
#   'food_250m': 0,
#   'food_500m': 0,
#   'id': 4685.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 33.08235247542634,
#   'bus_stop_250m': 2,
#   'bus_stop_500m': 4,
#   'gov_building_min_dist': 2533.061503187805,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 2141.2223715264527,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 3464.45474190533,
#   'school_250m': 0,
#   'school_500m': 0,
#   'kgarden_min_dist': 3629.1053606764754,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 281.9093574245876,
#   'office_250m': 0,
#   'office_500m': 1,
#   'food_min_dist': 145.43761144467254,
#   'food_250m': 2,
#   'food_500m': 4,
#   'id': 4703.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 2991.3129706660193,
#   'bus_stop_250m': 0,
#   'bus_stop_500m': 0,
#   'gov_building_min_dist': 1191.549362613294,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 63.60663904280538,
#   'college_250m': 5,
#   'college_500m': 6,
#   'school_min_dist': 335.66740669240386,
#   'school_250m': 0,
#   'school_500m': 1,
#   'kgarden_min_dist': 1887.8582352920234,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 301.37115212665043,
#   'office_250m': 0,
#   'office_500m': 1,
#   'food_min_dist': 383.4099388308308,
#   'food_250m': 0,
#   'food_500m': 2,
#   'id': 4712.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 6903.087495167567,
#   'bus_stop_250m': 0,
#   'bus_stop_500m': 0,
#   'gov_building_min_dist': 10000,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 8375.136964922985,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 6346.127948803999,
#   'school_250m': 0,
#   'school_500m': 0,
#   'kgarden_min_dist': 2582.880033518419,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 6916.128619356121,
#   'office_250m': 0,
#   'office_500m': 0,
#   'food_min_dist': 6472.4845771931505,
#   'food_250m': 0,
#   'food_500m': 0,
#   'id': 4713.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 3814.2829182676346,
#   'bus_stop_250m': 0,
#   'bus_stop_500m': 0,
#   'gov_building_min_dist': 10000,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 6692.095055363522,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 4143.515884361586,
#   'school_250m': 0,
#   'school_500m': 0,
#   'kgarden_min_dist': 49.413332273546295,
#   'kgarden_250m': 1,
#   'kgarden_500m': 1,
#   'office_min_dist': 41.703425005024165,
#   'office_250m': 19,
#   'office_500m': 33,
#   'food_min_dist': 524.2306383099697,
#   'food_250m': 0,
#   'food_500m': 0,
#   'id': 8483.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 283.63504493637834,
#   'bus_stop_250m': 0,
#   'bus_stop_500m': 2,
#   'gov_building_min_dist': 10000,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 2569.338312382219,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 531.717030205046,
#   'school_250m': 0,
#   'school_500m': 0,
#   'kgarden_min_dist': 1162.2765071104207,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 115.99716570881716,
#   'office_250m': 4,
#   'office_500m': 46,
#   'food_min_dist': 28.135687981498787,
#   'food_250m': 9,
#   'food_500m': 38,
#   'id': 8486.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 2740.69550080824,
#   'bus_stop_250m': 0,
#   'bus_stop_500m': 0,
#   'gov_building_min_dist': 10000,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 3015.3781119398177,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 258.0815180791662,
#   'school_250m': 0,
#   'school_500m': 1,
#   'kgarden_min_dist': 299.81077068805104,
#   'kgarden_250m': 0,
#   'kgarden_500m': 2,
#   'office_min_dist': 197.4921687115181,
#   'office_250m': 1,
#   'office_500m': 2,
#   'food_min_dist': 66.10100265951554,
#   'food_250m': 1,
#   'food_500m': 1,
#   'id': 8487.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 132.3245279548053,
#   'bus_stop_250m': 3,
#   'bus_stop_500m': 7,
#   'gov_building_min_dist': 1564.3503718169193,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 1019.7232178487478,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 1648.170975906052,
#   'school_250m': 0,
#   'school_500m': 0,
#   'kgarden_min_dist': 570.5121545911779,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 794.2274853224405,
#   'office_250m': 0,
#   'office_500m': 0,
#   'food_min_dist': 378.8802760214477,
#   'food_250m': 0,
#   'food_500m': 1,
#   'id': 8497.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 10000,
#   'bus_stop_250m': 0,
#   'bus_stop_500m': 0,
#   'gov_building_min_dist': 10000,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 10000,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 10000,
#   'school_250m': 0,
#   'school_500m': 0,
#   'kgarden_min_dist': 10000,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 10000,
#   'office_250m': 0,
#   'office_500m': 0,
#   'food_min_dist': 10000,
#   'food_250m': 0,
#   'food_500m': 0,
#   'id': 8500.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 10000,
#   'bus_stop_250m': 0,
#   'bus_stop_500m': 0,
#   'gov_building_min_dist': 10000,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 10000,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 854.4289541266496,
#   'school_250m': 0,
#   'school_500m': 0,
#   'kgarden_min_dist': 1803.0104353905228,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 10000,
#   'office_250m': 0,
#   'office_500m': 0,
#   'food_min_dist': 521.4990167249003,
#   'food_250m': 0,
#   'food_500m': 0,
#   'id': 8502.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 10000,
#   'bus_stop_250m': 0,
#   'bus_stop_500m': 0,
#   'gov_building_min_dist': 10000,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 10000,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 10000,
#   'school_250m': 0,
#   'school_500m': 0,
#   'kgarden_min_dist': 10000,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 10000,
#   'office_250m': 0,
#   'office_500m': 0,
#   'food_min_dist': 10000,
#   'food_250m': 0,
#   'food_500m': 0,
#   'id': 8511.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 10000,
#   'bus_stop_250m': 0,
#   'bus_stop_500m': 0,
#   'gov_building_min_dist': 10000,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 10000,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 836.1910923585104,
#   'school_250m': 0,
#   'school_500m': 0,
#   'kgarden_min_dist': 1058.4347283228556,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 3132.9752900119856,
#   'office_250m': 0,
#   'office_500m': 0,
#   'food_min_dist': 312.6521912883776,
#   'food_250m': 0,
#   'food_500m': 5,
#   'id': 8518.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 10000,
#   'bus_stop_250m': 0,
#   'bus_stop_500m': 0,
#   'gov_building_min_dist': 10000,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 1772.8677266941609,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 2365.519997754828,
#   'school_250m': 0,
#   'school_500m': 0,
#   'kgarden_min_dist': 2095.1444240933724,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 1441.6531936839958,
#   'office_250m': 0,
#   'office_500m': 0,
#   'food_min_dist': 574.983717999966,
#   'food_250m': 0,
#   'food_500m': 0,
#   'id': 8534.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 168.43705785172776,
#   'bus_stop_250m': 2,
#   'bus_stop_500m': 16,
#   'gov_building_min_dist': 6501.626696443022,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 126.45763072271419,
#   'college_250m': 1,
#   'college_500m': 1,
#   'school_min_dist': 198.90004093342068,
#   'school_250m': 1,
#   'school_500m': 3,
#   'kgarden_min_dist': 200.1524935606084,
#   'kgarden_250m': 2,
#   'kgarden_500m': 5,
#   'office_min_dist': 198.77394173598557,
#   'office_250m': 2,
#   'office_500m': 6,
#   'food_min_dist': 236.39882047306054,
#   'food_250m': 1,
#   'food_500m': 31,
#   'id': 8542.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 1599.3824456736681,
#   'bus_stop_250m': 0,
#   'bus_stop_500m': 0,
#   'gov_building_min_dist': 10000,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 2413.950181962846,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 635.9111038509103,
#   'school_250m': 0,
#   'school_500m': 0,
#   'kgarden_min_dist': 608.7943942408596,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 130.44733116287526,
#   'office_250m': 1,
#   'office_500m': 1,
#   'food_min_dist': 572.0511999621154,
#   'food_250m': 0,
#   'food_500m': 0,
#   'id': 8557.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 1357.9367591472203,
#   'bus_stop_250m': 0,
#   'bus_stop_500m': 0,
#   'gov_building_min_dist': 10000,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 10000,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 10000,
#   'school_250m': 0,
#   'school_500m': 0,
#   'kgarden_min_dist': 10000,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 10000,
#   'office_250m': 0,
#   'office_500m': 0,
#   'food_min_dist': 5700.740369722494,
#   'food_250m': 0,
#   'food_500m': 0,
#   'id': 8560.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 10000,
#   'bus_stop_250m': 0,
#   'bus_stop_500m': 0,
#   'gov_building_min_dist': 10000,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 10000,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 4918.452041335291,
#   'school_250m': 0,
#   'school_500m': 0,
#   'kgarden_min_dist': 6537.662265456334,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 4985.343360198562,
#   'office_250m': 0,
#   'office_500m': 0,
#   'food_min_dist': 965.3381704962306,
#   'food_250m': 0,
#   'food_500m': 0,
#   'id': 8566.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 213.99369636312443,
#   'bus_stop_250m': 2,
#   'bus_stop_500m': 5,
#   'gov_building_min_dist': 10000,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 1989.3261080320372,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 421.3986957715577,
#   'school_250m': 0,
#   'school_500m': 1,
#   'kgarden_min_dist': 1322.3066448930117,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 12.526448843351178,
#   'office_250m': 1,
#   'office_500m': 1,
#   'food_min_dist': 32.70238084560807,
#   'food_250m': 3,
#   'food_500m': 4,
#   'id': 8575.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 51.23158388506319,
#   'bus_stop_250m': 4,
#   'bus_stop_500m': 5,
#   'gov_building_min_dist': 10000,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
# ...
#   'office_500m': 0,
#   'food_min_dist': 672.1288197820343,
#   'food_250m': 0,
#   'food_500m': 0,
#   'id': 8303.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 116.4618134216957,
#   'bus_stop_250m': 2,
#   'bus_stop_500m': 5,
#   'gov_building_min_dist': 3309.617368345487,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 694.4495454022644,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 689.4612434032983,
#   'school_250m': 0,
#   'school_500m': 0,
#   'kgarden_min_dist': 896.4769312670167,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 214.04165398094952,
#   'office_250m': 1,
#   'office_500m': 7,
#   'food_min_dist': 102.64439166398775,
#   'food_250m': 5,
#   'food_500m': 11,
#   'id': 8305.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 109.43235215043738,
#   'bus_stop_250m': 3,
#   'bus_stop_500m': 19,
#   'gov_building_min_dist': 466.38613749170355,
#   'gov_building_250m': 0,
#   'gov_building_500m': 1,
#   'college_min_dist': 393.2379036614548,
#   'college_250m': 0,
#   'college_500m': 1,
#   'school_min_dist': 159.62988873046075,
#   'school_250m': 1,
#   'school_500m': 1,
#   'kgarden_min_dist': 3722.8323522161195,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 261.3769988492543,
#   'office_250m': 0,
#   'office_500m': 1,
#   'food_min_dist': 38.781615976959834,
#   'food_250m': 14,
#   'food_500m': 40,
#   'id': 8308.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 4915.224702995988,
#   'bus_stop_250m': 0,
#   'bus_stop_500m': 0,
#   'gov_building_min_dist': 10000,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 6469.146507826669,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 462.37690937016765,
#   'school_250m': 0,
#   'school_500m': 1,
#   'kgarden_min_dist': 808.5429484048324,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 502.55034899809436,
#   'office_250m': 0,
#   'office_500m': 0,
#   'food_min_dist': 421.11602015645065,
#   'food_250m': 0,
#   'food_500m': 1,
#   'id': 8320.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 41.79020327252794,
#   'bus_stop_250m': 5,
#   'bus_stop_500m': 10,
#   'gov_building_min_dist': 10000,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 10000,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 10000,
#   'school_250m': 0,
#   'school_500m': 0,
#   'kgarden_min_dist': 6924.155765957186,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 1336.2167545672469,
#   'office_250m': 0,
#   'office_500m': 0,
#   'food_min_dist': 16.530828331676794,
#   'food_250m': 2,
#   'food_500m': 8,
#   'id': 8321.0},
#  {'subway_min_dist': 1661.5530689302095,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 166.7302977774587,
#   'bus_stop_250m': 7,
#   'bus_stop_500m': 18,
#   'gov_building_min_dist': 1004.245997443409,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 1204.8859976005226,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 204.83608638800695,
#   'school_250m': 1,
#   'school_500m': 1,
#   'kgarden_min_dist': 531.1697009951096,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 492.8106769331832,
#   'office_250m': 0,
#   'office_500m': 1,
#   'food_min_dist': 110.28172589250073,
#   'food_250m': 4,
#   'food_500m': 10,
#   'id': 8332.0},
#  {'subway_min_dist': 388.6219044399661,
#   'subway_250m': 0,
#   'subway_500m': 2,
#   'bus_stop_min_dist': 83.94639246521905,
#   'bus_stop_250m': 4,
#   'bus_stop_500m': 12,
#   'gov_building_min_dist': 1281.4907010532595,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 1550.4835763193782,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 222.57185492313735,
#   'school_250m': 1,
#   'school_500m': 2,
#   'kgarden_min_dist': 1666.4814581782598,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 239.01823864985303,
#   'office_250m': 1,
#   'office_500m': 2,
#   'food_min_dist': 4.8346712202674285,
#   'food_250m': 2,
#   'food_500m': 5,
#   'id': 8333.0},
#  {'subway_min_dist': 388.6219044399661,
#   'subway_250m': 0,
#   'subway_500m': 2,
#   'bus_stop_min_dist': 83.94639246521905,
#   'bus_stop_250m': 4,
#   'bus_stop_500m': 12,
#   'gov_building_min_dist': 1281.4907010532595,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 1550.4835763193782,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 222.57185492313735,
#   'school_250m': 1,
#   'school_500m': 2,
#   'kgarden_min_dist': 1666.4814581782598,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 239.01823864985303,
#   'office_250m': 1,
#   'office_500m': 2,
#   'food_min_dist': 4.8346712202674285,
#   'food_250m': 2,
#   'food_500m': 5,
#   'id': 8334.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 10000,
#   'bus_stop_250m': 0,
#   'bus_stop_500m': 0,
#   'gov_building_min_dist': 10000,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 3644.0633883474725,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 1335.952449354011,
#   'school_250m': 0,
#   'school_500m': 0,
#   'kgarden_min_dist': 2430.942629900387,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 625.7737912206509,
#   'office_250m': 0,
#   'office_500m': 0,
#   'food_min_dist': 102.05432235565308,
#   'food_250m': 1,
#   'food_500m': 4,
#   'id': 8335.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 6658.170197480798,
#   'bus_stop_250m': 0,
#   'bus_stop_500m': 0,
#   'gov_building_min_dist': 10000,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 1582.1131214982715,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 7498.905120959146,
#   'school_250m': 0,
#   'school_500m': 0,
#   'kgarden_min_dist': 8236.121632361335,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 7576.107929418706,
#   'office_250m': 0,
#   'office_500m': 0,
#   'food_min_dist': 7.084536624849775,
#   'food_250m': 2,
#   'food_500m': 7,
#   'id': 8349.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 6658.170197480798,
#   'bus_stop_250m': 0,
#   'bus_stop_500m': 0,
#   'gov_building_min_dist': 10000,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 1582.1131214982715,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 7498.905120959146,
#   'school_250m': 0,
#   'school_500m': 0,
#   'kgarden_min_dist': 8236.121632361335,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 7576.107929418706,
#   'office_250m': 0,
#   'office_500m': 0,
#   'food_min_dist': 7.084536624849775,
#   'food_250m': 2,
#   'food_500m': 7,
#   'id': 8350.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 115.36234419276609,
#   'bus_stop_250m': 3,
#   'bus_stop_500m': 9,
#   'gov_building_min_dist': 10000,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 886.015176770943,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 216.84238422898943,
#   'school_250m': 1,
#   'school_500m': 1,
#   'kgarden_min_dist': 1087.6064711162758,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 990.0953369687331,
#   'office_250m': 0,
#   'office_500m': 0,
#   'food_min_dist': 115.20393002439545,
#   'food_250m': 2,
#   'food_500m': 5,
#   'id': 8357.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 107.89873393628838,
#   'bus_stop_250m': 2,
#   'bus_stop_500m': 2,
#   'gov_building_min_dist': 10000,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 6086.957288815253,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 2947.897192548936,
#   'school_250m': 0,
#   'school_500m': 0,
#   'kgarden_min_dist': 5936.985956258202,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 1387.1486270468677,
#   'office_250m': 0,
#   'office_500m': 0,
#   'food_min_dist': 1228.7435539268752,
#   'food_250m': 0,
#   'food_500m': 0,
#   'id': 2978.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 1023.1768614119343,
#   'bus_stop_250m': 0,
#   'bus_stop_500m': 0,
#   'gov_building_min_dist': 10000,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 10000,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 10000,
#   'school_250m': 0,
#   'school_500m': 0,
#   'kgarden_min_dist': 10000,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 10000,
#   'office_250m': 0,
#   'office_500m': 0,
#   'food_min_dist': 10000,
#   'food_250m': 0,
#   'food_500m': 0,
#   'id': 2982.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 339.77917535754756,
#   'bus_stop_250m': 0,
#   'bus_stop_500m': 1,
#   'gov_building_min_dist': 312.44092158674215,
#   'gov_building_250m': 0,
#   'gov_building_500m': 1,
#   'college_min_dist': 554.5237146372798,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 2073.299273229076,
#   'school_250m': 0,
#   'school_500m': 0,
#   'kgarden_min_dist': 678.0003224854563,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 399.1117145333743,
#   'office_250m': 0,
#   'office_500m': 1,
#   'food_min_dist': 8.16974363841602,
#   'food_250m': 1,
#   'food_500m': 1,
#   'id': 2985.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 195.25653118753297,
#   'bus_stop_250m': 2,
#   'bus_stop_500m': 2,
#   'gov_building_min_dist': 10000,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 3027.859633540186,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 535.460444590697,
#   'school_250m': 0,
#   'school_500m': 0,
#   'kgarden_min_dist': 2057.521485429912,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 762.2004022625222,
#   'office_250m': 0,
#   'office_500m': 0,
#   'food_min_dist': 255.24166595078208,
#   'food_250m': 0,
#   'food_500m': 3,
#   'id': 2995.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 157.21872868593385,
#   'bus_stop_250m': 4,
#   'bus_stop_500m': 10,
#   'gov_building_min_dist': 5538.6680939213165,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 839.560616370886,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 3161.7317152941023,
#   'school_250m': 0,
#   'school_500m': 0,
#   'kgarden_min_dist': 784.9884918971703,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 711.7727330049865,
#   'office_250m': 0,
#   'office_500m': 0,
#   'food_min_dist': 29.47932039314301,
#   'food_250m': 1,
#   'food_500m': 4,
#   'id': 3004.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 3096.4878145576727,
#   'bus_stop_250m': 0,
#   'bus_stop_500m': 0,
#   'gov_building_min_dist': 10000,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 10000,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 262.8921817510631,
#   'school_250m': 0,
#   'school_500m': 1,
#   'kgarden_min_dist': 10000,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 345.7075326236666,
#   'office_250m': 0,
#   'office_500m': 1,
#   'food_min_dist': 225.38659201265082,
#   'food_250m': 2,
#   'food_500m': 4,
#   'id': 3007.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 1038.2859600536362,
#   'bus_stop_250m': 0,
#   'bus_stop_500m': 0,
#   'gov_building_min_dist': 1968.825250226717,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 1324.030124793815,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 1207.6877064996372,
#   'school_250m': 0,
#   'school_500m': 0,
#   'kgarden_min_dist': 2247.576461276698,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 1368.2362302770296,
#   'office_250m': 0,
#   'office_500m': 0,
#   'food_min_dist': 96.58559792394236,
#   'food_250m': 3,
#   'food_500m': 3,
#   'id': 3009.0},
#  {'subway_min_dist': 1211.0542220631212,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 64.870995681837,
#   'bus_stop_250m': 2,
#   'bus_stop_500m': 5,
#   'gov_building_min_dist': 6154.906280551042,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 5375.130989109042,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 1378.1770112060278,
#   'school_250m': 0,
#   'school_500m': 0,
#   'kgarden_min_dist': 754.4660217692176,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 862.3766881423991,
#   'office_250m': 0,
#   'office_500m': 0,
#   'food_min_dist': 335.0213342779304,
#   'food_250m': 0,
#   'food_500m': 3,
#   'id': 3010.0},
#  {'subway_min_dist': 533.2683435535783,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 76.50973291187499,
#   'bus_stop_250m': 6,
#   'bus_stop_500m': 14,
#   'gov_building_min_dist': 1343.4086378646364,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 472.4747855693881,
#   'college_250m': 0,
#   'college_500m': 1,
#   'school_min_dist': 421.784948232063,
#   'school_250m': 0,
#   'school_500m': 2,
#   'kgarden_min_dist': 372.24902103257006,
#   'kgarden_250m': 0,
#   'kgarden_500m': 2,
#   'office_min_dist': 5.928970584791695,
#   'office_250m': 4,
#   'office_500m': 31,
#   'food_min_dist': 18.994982488051793,
#   'food_250m': 47,
#   'food_500m': 143,
#   'id': 3011.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 10000,
#   'bus_stop_250m': 0,
#   'bus_stop_500m': 0,
#   'gov_building_min_dist': 10000,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 10000,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 1059.8705196648,
#   'school_250m': 0,
#   'school_500m': 0,
#   'kgarden_min_dist': 1167.98433083666,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 3045.598843856248,
#   'office_250m': 0,
#   'office_500m': 0,
#   'food_min_dist': 14.915110605353819,
#   'food_250m': 1,
#   'food_500m': 5,
#   'id': 3014.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 338.80102899449247,
#   'bus_stop_250m': 0,
#   'bus_stop_500m': 2,
#   'gov_building_min_dist': 10000,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 8626.616121711952,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 6343.772526733741,
#   'school_250m': 0,
#   'school_500m': 0,
#   'kgarden_min_dist': 4123.041485723422,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 511.32721334821576,
#   'office_250m': 0,
#   'office_500m': 0,
#   'food_min_dist': 94.63733180084178,
#   'food_250m': 1,
#   'food_500m': 4,
#   'id': 3020.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 2387.182764633812,
#   'bus_stop_250m': 0,
#   'bus_stop_500m': 0,
#   'gov_building_min_dist': 10000,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 3073.3559077774953,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 453.98654706317404,
#   'school_250m': 0,
#   'school_500m': 1,
#   'kgarden_min_dist': 2083.4081444471235,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 449.26328336414855,
#   'office_250m': 0,
#   'office_500m': 1,
#   'food_min_dist': 69.53539369980754,
#   'food_250m': 1,
#   'food_500m': 6,
#   'id': 3026.0},
#  {'subway_min_dist': 10000,
#   'subway_250m': 0,
#   'subway_500m': 0,
#   'bus_stop_min_dist': 629.5311028069815,
#   'bus_stop_250m': 0,
#   'bus_stop_500m': 0,
#   'gov_building_min_dist': 10000,
#   'gov_building_250m': 0,
#   'gov_building_500m': 0,
#   'college_min_dist': 1953.4782861124118,
#   'college_250m': 0,
#   'college_500m': 0,
#   'school_min_dist': 1273.326837822562,
#   'school_250m': 0,
#   'school_500m': 0,
#   'kgarden_min_dist': 561.6413532260682,
#   'kgarden_250m': 0,
#   'kgarden_500m': 0,
#   'office_min_dist': 212.22520570535093,
#   'office_250m': 1,
#   'office_500m': 1,
#   'food_min_dist': 215.25970379947304,
#   'food_250m': 1,
#   'food_500m': 2,
#   'id': 3034.0},
#  ...]
